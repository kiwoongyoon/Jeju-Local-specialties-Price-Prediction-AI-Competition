# %%
import os
import random
import numpy as np
import pandas as pd
from datetime import datetime
from holidays import country_holidays
from xgboost import XGBRegressor 
import xgboost as xgb 
from tqdm import tqdm

import optuna 
from optuna.samplers import TPESampler

from supervised.automl import AutoML

import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader

from sklearn.impute import KNNImputer
from sklearn.preprocessing import PolynomialFeatures, LabelEncoder
from sklearn import base
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error
from sklearn.model_selection import KFold
from sklearn.preprocessing import LabelEncoder
from sklearn.ensemble import RandomForestRegressor

import warnings
warnings.filterwarnings(action='ignore') 

def seed_everything(seed):
    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    np.random.seed(seed)

seed_everything(42) # Seed 고정
## Load Data
train_df = pd.read_csv('../../DATA/train.csv')
test_df  = pd.read_csv('../../DATA/test.csv')

# %%
## Make Date Data
# 데이터 타입 변경, 열 이름 변경 

new_column_names = {
    'corporation': 'corp',
    'location': 'loc',
    'supply(kg)': 'supply',
    'price(원/kg)': 'price',
}
train_df = train_df.rename(columns=new_column_names)
test_df = test_df.rename(columns=new_column_names)
train_df['timestamp']  = pd.to_datetime(train_df['timestamp'])
test_df['timestamp']  = pd.to_datetime(test_df['timestamp'])

def get_date_info(data) :
    # data의 날짜 정보 추출하기 
    data['year'] = data['timestamp'].dt.year
    data['month'] = data['timestamp'].dt.month
    data['day'] = data['timestamp'].dt.day
    data['weekday'] = data['timestamp'].dt.weekday
    data['weekofyear'] = data['timestamp'].dt.isocalendar().week
    data['dayofyear'] = data['timestamp'].dt.dayofyear #해당 년도의 몇 일째 

def month_to_season(month):
    if month in [12, 1, 2]:
        return 'Winter'
    elif month in [3, 4, 5]:
        return 'Spring'
    elif month in [6, 7, 8]:
        return 'Summer'
    else:
        return 'Fall'

    
get_date_info(train_df)
get_date_info(test_df)

# 'month' 칼럼을 정수형으로 변환
train_df['season'] = train_df['month'].astype(int).apply(month_to_season)
test_df['season'] = test_df['month'].astype(int).apply(month_to_season)

# %%
# 휴일 정보 추가하니 성능 더 하락 

years  = [2019,2020,2021,2022,2023 ]
holi_dates=[]
for year in years :
    holidayarr = country_holidays('KR', years = year).items()
    for day in holidayarr:
        holi_dates.append(day[0])
    
print(holi_dates[0])

train_df['holi'] = train_df['timestamp'].apply(lambda x: int(x in holi_dates))
test_df['holi'] = test_df['timestamp'].apply(lambda x: int(x in holi_dates))
train_df.loc[(train_df['holi'] == 0) & (train_df['weekday'] >= 6), 'holi'] = 1
test_df.loc[(train_df['holi'] == 0) & (test_df['weekday'] >= 6), 'holi'] = 1
# Out:
# 2019-01-01

# %%
def trans_fourier(data) :
    #날짜
    data['sin_date'] = -np.sin(2 * np.pi * (data['month']+data['day']/31)/12)
    data['cos_date'] = -np.cos(2 * np.pi * (data['month']+data['day']/31)/12)

    #월
    data['sin_month'] = -np.sin(2 * np.pi * data['month']/12.0)
    data['cos_month'] = -np.cos(2 * np.pi * data['month']/12.0)
    
    data['sin_week'] = -np.sin(2 * np.pi * (data['weekofyear'])/52.0)
    data['cos_week'] = -np.cos(2 * np.pi * (data['weekofyear'])/52.0)

    #요일
    data['sin_dayofweek'] = -np.sin(2 * np.pi * (data['weekday']+1)/7.0)
    data['cos_dayofweek'] = -np.cos(2 * np.pi * (data['weekday']+1)/7.0)
    
    
trans_fourier(train_df)
trans_fourier(test_df)

# %%
# Supply Data , New feature
# 아이템, 유통회사, 지역 묶기 
def new_columns(data):
    data['item_loc']= data['item'].astype(str).str.cat([ data['loc'].astype(str)], sep='')
    # data['item_corp']= data['item'].astype(str).str.cat([data['corp'].astype(str)], sep='')
    # data['item_loc']= data['item'].astype(str).str.cat([data['loc'].astype(str)], sep='')
    # data['item_loc'] =data['item_loc'].astype(str) 
    # data['item_corp'] = data['item_corp'].astype(str)
    # data['item_corp_loc']= data['item_corp_loc'].astype(str)
    
    # data['y_it_loc_m'] = data['item'].str.cat([data['loc'], data['year'].astype(str),data['month'].astype(str)], sep = '')

new_columns(train_df)
new_columns(test_df)

# %%
def fill_supply(train, test, start, end):
    train['timestamp'] = pd.to_datetime(train['timestamp'])  
    start_date = pd.to_datetime(start)
    end_date = pd.to_datetime(end)
    mask = (train['timestamp'] >= start_date) & (train['timestamp'] <= end_date)
    filtered_train_df = train.loc[mask]

    result = filtered_train_df.groupby('item_loc')['supply'].median()
    result = result.reset_index().rename(columns={'supply': 'supply'})

    test['supply'] = 0 
    test = test.set_index('item_loc')
    test.update(result.set_index('item_loc'))
    test = test.reset_index()

    return test 

test_df = fill_supply(train_df, test_df, "2023-01-11","2023-03-03")

# %%
# Imputaion Of Data 
# Encoding Categorical Features

class KFoldTargetEncoderTrain(base.BaseEstimator, base.TransformerMixin):
   
    def __init__(self,colnames,targetName,
                  n_fold=5, verbosity=True,
                  discardOriginal_col=False):
        self.colnames = colnames
        self.targetName = targetName
        self.n_fold = n_fold
        self.verbosity = verbosity
        self.discardOriginal_col = discardOriginal_col
        
    def fit(self, X, y=None):
        return self
    
    def transform(self,X):        
        assert(type(self.targetName) == str)
        assert(type(self.colnames) == str)
        assert(self.colnames in X.columns)
        assert(self.targetName in X.columns)       
        
        mean_of_target = X[self.targetName].mean()
        kf = KFold(n_splits = self.n_fold,
                   shuffle = True)        
        col_mean_name = self.colnames + '_' + 'encod'
        X[col_mean_name] = np.nan       
        
        for tr_ind, val_ind in kf.split(X):
            X_tr, X_val = X.iloc[tr_ind], X.iloc[val_ind]
            X.loc[X.index[val_ind], col_mean_name] = X_val[self.colnames].map(X_tr.groupby(self.colnames)[self.targetName].mean())
            X[col_mean_name].fillna(mean_of_target, inplace = True)  
            
        if self.verbosity:            
            encoded_feature = X[col_mean_name].values
            print('Correlation between the new feature, {} and, {} is {}.'.format(col_mean_name,self.targetName,                                                                                    np.corrcoef(X[self.targetName].values,encoded_feature)[0][1]))

        if self.discardOriginal_col:
            X = X.drop(self.targetName, axis=1)
        return X
class KFoldTargetEncoderTest(base.BaseEstimator, base.TransformerMixin):
    def __init__(self,train,colNames,encodedName):
        self.train = train
        self.colNames = colNames
        self.encodedName = encodedName
    def fit(self, X, y=None):
        return self
    def transform(self,X):
        mean = self.train[[self.colNames,
        self.encodedName]].groupby(
        self.colNames).mean().reset_index()
        dd = {}
        for row in (mean.itertuples(index=False)):
            dd[row[0]] = row[1]
            X[self.encodedName] = X[self.colNames]
            X[self.encodedName] = X[self.encodedName].map(dd.get)
        return X

# %%
#질적 변수들을 수치화합니다
qual_col = ['item', 'corp', 'loc']

for i in qual_col:
    le = LabelEncoder()
    train_df[i]=le.fit_transform(train_df[i])
    test_df[i]=le.transform(test_df[i]) #test 데이터에 대해서 fit하는 것은 data leakage에 해당합니다

# %%
# # ,'item' ,'corp', 'loc' 

# for col in ['item_loc' ,'season']:
#     t_encoder = KFoldTargetEncoderTrain(colnames=col , targetName='price',n_fold=5)
#     train_df  = t_encoder.fit_transform(train_df)
    
#     newcolname = f'{col}_encod'
    
#     test_t_encoder = KFoldTargetEncoderTest(train_df, colNames=col , encodedName=newcolname)
#     test_df = test_t_encoder.transform(test_df)
# Out:
# Correlation between the new feature, item_loc_encod and, price is 0.6139104258203091.
# Correlation between the new feature, season_encod and, price is 0.1430650204757649.

# %%
train_df.columns
# Out:
# Index(['ID', 'timestamp', 'item', 'corp', 'loc', 'supply', 'price', 'year',
#        'month', 'day', 'weekday', 'weekofyear', 'dayofyear', 'season', 'holi',
#        'sin_date', 'cos_date', 'sin_month', 'cos_month', 'sin_week',
#        'cos_week', 'sin_dayofweek', 'cos_dayofweek', 'item_loc',
#        'item_loc_encod', 'season_encod'],
#       dtype='object')

# %%
# 질적 변수들을 수치화합니다
qual_col = ['item_loc' ,'season']

def encode_cols_v1(data,data2, cat_name , target , weight) :
    mean = data[target].mean()
    agg = data.groupby(cat_name)[target].agg(['count','mean'])
    counts =agg['count']
    means  =agg['mean']
    
    smooth = (counts*means + weight*mean)/ (counts+weight)
    data[cat_name] = data[cat_name].map(smooth) 
    data2[cat_name] = data2[cat_name].map(smooth)
    
    return data, data2 
    


for i in qual_col:
    train_df, test_df = encode_cols_v1(train_df,test_df, i, 'price', 5)

# scaler로 스케일링 해주기

# %%
train_df
# Out:
#                     ID  timestamp  item  corp  loc    supply   price  year  \
# 0      TG_A_J_20190101 2019-01-01     4     0    0       0.0     0.0  2019
# 1      TG_A_J_20190102 2019-01-02     4     0    0       0.0     0.0  2019
# 2      TG_A_J_20190103 2019-01-03     4     0    0   60601.0  1728.0  2019
# 3      TG_A_J_20190104 2019-01-04     4     0    0   25000.0  1408.0  2019
# 4      TG_A_J_20190105 2019-01-05     4     0    0   32352.0  1250.0  2019
# ...                ...        ...   ...   ...  ...       ...     ...   ...
# 59392  RD_F_J_20230227 2023-02-27     3     5    0  452440.0   468.0  2023
# 59393  RD_F_J_20230228 2023-02-28     3     5    0  421980.0   531.0  2023
# 59394  RD_F_J_20230301 2023-03-01     3     5    0  382980.0   574.0  2023
# 59395  RD_F_J_20230302 2023-03-02     3     5    0  477220.0   523.0  2023
# 59396  RD_F_J_20230303 2023-03-03     3     5    0  427520.0   529.0  2023
#
#        month  day  ...  holi  sin_date  cos_date  sin_month     cos_month  \
# 0          1    1  ...     0 -0.514555 -0.857457  -0.500000 -8.660254e-01
# 1          1    2  ...     0 -0.528964 -0.848644  -0.500000 -8.660254e-01
# 2          1    3  ...     0 -0.543222 -0.839589  -0.500000 -8.660254e-01
# 3          1    4  ...     0 -0.557324 -0.830295  -0.500000 -8.660254e-01
# 4          1    5  ...     0 -0.571268 -0.820763  -0.500000 -8.660254e-01
# ...      ...  ...  ...   ...       ...       ...        ...           ...
# 59392      2   27  ...     0 -0.997719 -0.067510  -0.866025 -5.000000e-01
# 59393      2   28  ...     0 -0.998717 -0.050649  -0.866025 -5.000000e-01
# 59394      3    1  ...     0 -0.999857  0.016889  -1.000000 -6.123234e-17
# 59395      3    2  ...     0 -0.999429  0.033774  -1.000000 -6.123234e-17
# 59396      3    3  ...     0 -0.998717  0.050649  -1.000000 -6.123234e-17
#
#        sin_week  cos_week  sin_dayofweek  cos_dayofweek     item_loc
# 0     -0.120537 -0.992709      -0.974928       0.222521  3005.308058
# 1     -0.120537 -0.992709      -0.433884       0.900969  3005.308058
# 2     -0.120537 -0.992709       0.433884       0.900969  3005.308058
# 3     -0.120537 -0.992709       0.974928       0.222521  3005.308058
# 4     -0.120537 -0.992709       0.781831      -0.623490  3005.308058
# ...         ...       ...            ...            ...          ...
# 59392 -0.885456 -0.464723      -0.781831      -0.623490   252.715500
# 59393 -0.885456 -0.464723      -0.974928       0.222521   252.715500
# 59394 -0.885456 -0.464723      -0.433884       0.900969   252.715500
# 59395 -0.885456 -0.464723       0.433884       0.900969   252.715500
# 59396 -0.885456 -0.464723       0.974928       0.222521   252.715500
#
# [59397 rows x 24 columns]

# %%
#학습에 사용하지 않을 변수들을 제거합니다
# train_x = train_df.drop(columns=['ID','season', 'timestamp', 'price', 'day', 'month', 'weekday','item_loc','dayofyear','season','loc','item'])
# train_y = train_df['price']
# test_x = test_df.drop(columns=['ID', 'season','timestamp' ,  'day', 'month', 'weekday', 'item_loc','dayofyear','season', 'loc', 'item'])

train_x = train_df.drop(columns=['ID', 'timestamp', 'price', 'day', 'month', 'weekday','dayofyear','loc','item'])
train_y = train_df['price']
test_x = test_df.drop(columns=['ID','timestamp' ,  'day', 'month', 'weekday','dayofyear', 'loc', 'item'])

# %%
train_x
# Out:
#        corp    supply  year  weekofyear       season  holi  sin_date  \
# 0         0       0.0  2019           1   993.653610     0 -0.514555
# 1         0       0.0  2019           1   993.653610     0 -0.528964
# 2         0   60601.0  2019           1   993.653610     0 -0.543222
# 3         0   25000.0  2019           1   993.653610     0 -0.557324
# 4         0   32352.0  2019           1   993.653610     0 -0.571268
# ...     ...       ...   ...         ...          ...   ...       ...
# 59392     5  452440.0  2023           9   993.653610     0 -0.997719
# 59393     5  421980.0  2023           9   993.653610     0 -0.998717
# 59394     5  382980.0  2023           9  1531.028493     0 -0.999857
# 59395     5  477220.0  2023           9  1531.028493     0 -0.999429
# 59396     5  427520.0  2023           9  1531.028493     0 -0.998717
#
#        cos_date  sin_month     cos_month  sin_week  cos_week  sin_dayofweek  \
# 0     -0.857457  -0.500000 -8.660254e-01 -0.120537 -0.992709      -0.974928
# 1     -0.848644  -0.500000 -8.660254e-01 -0.120537 -0.992709      -0.433884
# 2     -0.839589  -0.500000 -8.660254e-01 -0.120537 -0.992709       0.433884
# 3     -0.830295  -0.500000 -8.660254e-01 -0.120537 -0.992709       0.974928
# 4     -0.820763  -0.500000 -8.660254e-01 -0.120537 -0.992709       0.781831
# ...         ...        ...           ...       ...       ...            ...
# 59392 -0.067510  -0.866025 -5.000000e-01 -0.885456 -0.464723      -0.781831
# 59393 -0.050649  -0.866025 -5.000000e-01 -0.885456 -0.464723      -0.974928
# 59394  0.016889  -1.000000 -6.123234e-17 -0.885456 -0.464723      -0.433884
# 59395  0.033774  -1.000000 -6.123234e-17 -0.885456 -0.464723       0.433884
# 59396  0.050649  -1.000000 -6.123234e-17 -0.885456 -0.464723       0.974928
#
#        cos_dayofweek     item_loc
# 0           0.222521  3005.308058
# 1           0.900969  3005.308058
# 2           0.900969  3005.308058
# 3           0.222521  3005.308058
# 4          -0.623490  3005.308058
# ...              ...          ...
# 59392      -0.623490   252.715500
# 59393       0.222521   252.715500
# 59394       0.900969   252.715500
# 59395       0.900969   252.715500
# 59396       0.222521   252.715500
#
# [59397 rows x 15 columns]

# %%
# 데이터 스플릿 
X_train, X_valid , y_train , y_valid  = train_test_split(train_x,train_y, shuffle=True,test_size=0.2)

# %%
#XGB optuna 하기

def RMSE(true, pred):
    mse = np.mean((true - pred) ** 2)
    rmse = np.sqrt(mse)
    
    return rmse


def objective(trial, train_x, train_y, val_x, val_y):
    
    param = {
        'lambda': trial.suggest_float('lambda', 1e-3, 0.1),
        'alpha': trial.suggest_float('alpha', 1e-3, 1.0),
        'colsample_bytree': trial.suggest_float('colsample_bytree', 0.4, 1),
        'subsample': trial.suggest_float('subsample', 0.4, 1),
        'learning_rate': trial.suggest_float('learning_rate',0.0001, 0.1),
        'n_estimators': trial.suggest_int('n_estimators', 100, 1000),
        'max_depth': trial.suggest_int('max_depth', 4,8),
        'min_child_weight': trial.suggest_int('min_child_weight', 2, 50),
    }
    model =XGBRegressor(**param)  
    model.fit(train_x, train_y)
    preds = model.predict(val_x)
    score = RMSE(val_y, np.round(preds,0))
    
    return score
          
# study_xgb.optimize(objective, n_trials=5)
study =  optuna.create_study(study_name='Xgb', direction='minimize',sampler=TPESampler(seed=42) )
study.optimize(lambda trial: objective(trial,X_train,  y_train ,X_valid , y_valid ),n_trials=200, timeout = 3000 )
print('Best trial:', study.best_trial.params)
print('Best score:', study.best_value)
# Out:
# [I 2023-11-03 23:48:30,641] A new study created in memory with name: Xgb
# [I 2023-11-03 23:48:30,871] Trial 0 finished with value: 612.8815699391228 and parameters: {'lambda': 0.03807947176588889, 'alpha': 0.9507635921035062, 'colsample_bytree': 0.839196365086843, 'subsample': 0.759195090518222, 'learning_rate': 0.01568626218019941, 'n_estimators': 240, 'max_depth': 4, 'min_child_weight': 44}. Best is trial 0 with value: 612.8815699391228.
# [I 2023-11-03 23:48:31,017] Trial 1 finished with value: 562.7933449839729 and parameters: {'lambda': 0.06051038616257767, 'alpha': 0.7083645052182495, 'colsample_bytree': 0.41235069657748147, 'subsample': 0.9819459112971965, 'learning_rate': 0.08326101981596214, 'n_estimators': 291, 'max_depth': 4, 'min_child_weight': 10}. Best is trial 1 with value: 562.7933449839729.
# [I 2023-11-03 23:48:31,165] Trial 2 finished with value: 527.8309198657558 and parameters: {'lambda': 0.03111998205299424, 'alpha': 0.5252316752006057, 'colsample_bytree': 0.6591670111852694, 'subsample': 0.5747374841188252, 'learning_rate': 0.061224104182765714, 'n_estimators': 225, 'max_depth': 5, 'min_child_weight': 19}. Best is trial 2 with value: 527.8309198657558.
# [I 2023-11-03 23:48:31,430] Trial 3 finished with value: 508.95525078969104 and parameters: {'lambda': 0.04615092843748656, 'alpha': 0.7853907854316206, 'colsample_bytree': 0.5198042692950159, 'subsample': 0.708540663048167, 'learning_rate': 0.059282215429318046, 'n_estimators': 141, 'max_depth': 7, 'min_child_weight': 10}. Best is trial 3 with value: 508.95525078969104.
# [I 2023-11-03 23:48:32,061] Trial 4 finished with value: 484.8382121938895 and parameters: {'lambda': 0.0074401077055426725, 'alpha': 0.9489366517160799, 'colsample_bytree': 0.9793792198447356, 'subsample': 0.8850384088698766, 'learning_rate': 0.030530915540419732, 'n_estimators': 188, 'max_depth': 7, 'min_child_weight': 23}. Best is trial 4 with value: 484.8382121938895.
# [I 2023-11-03 23:48:32,979] Trial 5 finished with value: 539.6528938821888 and parameters: {'lambda': 0.013081785249633104, 'alpha': 0.49568173320115894, 'colsample_bytree': 0.42063311266913106, 'subsample': 0.9455922412472693, 'learning_rate': 0.02595212016184169, 'n_estimators': 696, 'max_depth': 5, 'min_child_weight': 27}. Best is trial 4 with value: 484.8382121938895.
# [I 2023-11-03 23:48:33,749] Trial 6 finished with value: 461.63947090156415 and parameters: {'lambda': 0.05512431765498469, 'alpha': 0.18566960107000152, 'colsample_bytree': 0.9817507766587351, 'subsample': 0.8650796940166687, 'learning_rate': 0.0939559442622625, 'n_estimators': 906, 'max_depth': 6, 'min_child_weight': 47}. Best is trial 6 with value: 461.63947090156415.
# [I 2023-11-03 23:48:34,229] Trial 7 finished with value: 497.4694699868762 and parameters: {'lambda': 0.00976075770314003, 'alpha': 0.19678687955672605, 'colsample_bytree': 0.4271363733463229, 'subsample': 0.5951981984579586, 'learning_rate': 0.038928861239979254, 'n_estimators': 344, 'max_depth': 8, 'min_child_weight': 19}. Best is trial 6 with value: 461.63947090156415.
# [I 2023-11-03 23:48:35,402] Trial 8 finished with value: 514.2453006190277 and parameters: {'lambda': 0.028812516459050697, 'alpha': 0.5431533870750902, 'colsample_bytree': 0.4845545349848576, 'subsample': 0.8813181884524238, 'learning_rate': 0.007547609303609106, 'n_estimators': 989, 'max_depth': 7, 'min_child_weight': 11}. Best is trial 6 with value: 461.63947090156415.
# [I 2023-11-03 23:48:35,657] Trial 9 finished with value: 512.5799451484131 and parameters: {'lambda': 0.0015466895952366377, 'alpha': 0.8156459670263794, 'colsample_bytree': 0.8241144063085704, 'subsample': 0.8374043008245924, 'learning_rate': 0.07714990763392598, 'n_estimators': 166, 'max_depth': 5, 'min_child_weight': 7}. Best is trial 6 with value: 461.63947090156415.
# [I 2023-11-03 23:48:36,263] Trial 10 finished with value: 470.0637172047245 and parameters: {'lambda': 0.08724965535925201, 'alpha': 0.006991185772861341, 'colsample_bytree': 0.9817222664727197, 'subsample': 0.4107771253688918, 'learning_rate': 0.09838903419300483, 'n_estimators': 917, 'max_depth': 6, 'min_child_weight': 49}. Best is trial 6 with value: 461.63947090156415.
# [I 2023-11-03 23:48:37,128] Trial 11 finished with value: 471.38850588962015 and parameters: {'lambda': 0.08823586957713772, 'alpha': 0.0046221687064701734, 'colsample_bytree': 0.995442498004112, 'subsample': 0.4103116901613753, 'learning_rate': 0.09739462884197035, 'n_estimators': 993, 'max_depth': 6, 'min_child_weight': 49}. Best is trial 6 with value: 461.63947090156415.
# [I 2023-11-03 23:48:37,981] Trial 12 finished with value: 473.99503417677533 and parameters: {'lambda': 0.09914510906275917, 'alpha': 0.005177479200044619, 'colsample_bytree': 0.9115001002765166, 'subsample': 0.40394027312758135, 'learning_rate': 0.09703444615775657, 'n_estimators': 794, 'max_depth': 6, 'min_child_weight': 38}. Best is trial 6 with value: 461.63947090156415.
# [I 2023-11-03 23:48:38,539] Trial 13 finished with value: 461.10316638525165 and parameters: {'lambda': 0.07041509694398221, 'alpha': 0.16608280710261253, 'colsample_bytree': 0.8920983489739954, 'subsample': 0.7868767216042064, 'learning_rate': 0.08027407729177935, 'n_estimators': 809, 'max_depth': 6, 'min_child_weight': 36}. Best is trial 13 with value: 461.10316638525165.
# [I 2023-11-03 23:48:39,091] Trial 14 finished with value: 450.1017221355193 and parameters: {'lambda': 0.06229761986300517, 'alpha': 0.24231337804735953, 'colsample_bytree': 0.8601476864435449, 'subsample': 0.7868042111608514, 'learning_rate': 0.07892932507728818, 'n_estimators': 545, 'max_depth': 8, 'min_child_weight': 36}. Best is trial 14 with value: 450.1017221355193.
# [I 2023-11-03 23:48:39,830] Trial 15 finished with value: 452.3750230149886 and parameters: {'lambda': 0.06783546877171139, 'alpha': 0.2900959969215958, 'colsample_bytree': 0.8091057294985109, 'subsample': 0.7812488417029072, 'learning_rate': 0.07282850861162926, 'n_estimators': 483, 'max_depth': 8, 'min_child_weight': 34}. Best is trial 14 with value: 450.1017221355193.
# [I 2023-11-03 23:48:40,480] Trial 16 finished with value: 453.201847854783 and parameters: {'lambda': 0.06658919274987637, 'alpha': 0.35217013647507867, 'colsample_bytree': 0.7506246984793575, 'subsample': 0.7770277479667912, 'learning_rate': 0.06708745974622815, 'n_estimators': 468, 'max_depth': 8, 'min_child_weight': 33}. Best is trial 14 with value: 450.1017221355193.
# [I 2023-11-03 23:48:41,023] Trial 17 finished with value: 456.7945360314067 and parameters: {'lambda': 0.07537654247809059, 'alpha': 0.3285423883586212, 'colsample_bytree': 0.7250705796040899, 'subsample': 0.6875095377158316, 'learning_rate': 0.05180273544730506, 'n_estimators': 544, 'max_depth': 8, 'min_child_weight': 31}. Best is trial 14 with value: 450.1017221355193.
# [I 2023-11-03 23:48:41,467] Trial 18 finished with value: 452.91630727685924 and parameters: {'lambda': 0.059010854331331665, 'alpha': 0.3030799179861968, 'colsample_bytree': 0.7918460867426672, 'subsample': 0.9279703743994814, 'learning_rate': 0.07077907429532865, 'n_estimators': 452, 'max_depth': 8, 'min_child_weight': 41}. Best is trial 14 with value: 450.1017221355193.
# [I 2023-11-03 23:48:41,988] Trial 19 finished with value: 456.0776772032344 and parameters: {'lambda': 0.07326038121648813, 'alpha': 0.361318517808551, 'colsample_bytree': 0.6706027345694531, 'subsample': 0.8172752845324329, 'learning_rate': 0.0521087503365333, 'n_estimators': 642, 'max_depth': 7, 'min_child_weight': 29}. Best is trial 14 with value: 450.1017221355193.
# [I 2023-11-03 23:48:42,383] Trial 20 finished with value: 450.7851201838017 and parameters: {'lambda': 0.05185356722007306, 'alpha': 0.12388284886800224, 'colsample_bytree': 0.8924261590404028, 'subsample': 0.7231568818351396, 'learning_rate': 0.08585547991987111, 'n_estimators': 406, 'max_depth': 8, 'min_child_weight': 37}. Best is trial 14 with value: 450.1017221355193.
# [I 2023-11-03 23:48:42,876] Trial 21 finished with value: 450.018009460048 and parameters: {'lambda': 0.047587124519779644, 'alpha': 0.12022875313592757, 'colsample_bytree': 0.8859979855508893, 'subsample': 0.7190342297818089, 'learning_rate': 0.08135641965700632, 'n_estimators': 387, 'max_depth': 8, 'min_child_weight': 37}. Best is trial 21 with value: 450.018009460048.
# [I 2023-11-03 23:48:43,713] Trial 22 finished with value: 457.9355419773187 and parameters: {'lambda': 0.04651611813306782, 'alpha': 0.11596378609370422, 'colsample_bytree': 0.8943477423066573, 'subsample': 0.7160893490291274, 'learning_rate': 0.08712115271912697, 'n_estimators': 376, 'max_depth': 7, 'min_child_weight': 41}. Best is trial 21 with value: 450.018009460048.
# [I 2023-11-03 23:48:44,275] Trial 23 finished with value: 454.1374696388378 and parameters: {'lambda': 0.04861356853898918, 'alpha': 0.09600213227970937, 'colsample_bytree': 0.871814030653206, 'subsample': 0.6648095466925358, 'learning_rate': 0.08626184182813901, 'n_estimators': 586, 'max_depth': 8, 'min_child_weight': 39}. Best is trial 21 with value: 450.018009460048.
# [I 2023-11-03 23:48:44,718] Trial 24 finished with value: 452.552867142528 and parameters: {'lambda': 0.054065500144930244, 'alpha': 0.24027158223847878, 'colsample_bytree': 0.930893281492608, 'subsample': 0.7335125499714811, 'learning_rate': 0.07653360981156296, 'n_estimators': 353, 'max_depth': 8, 'min_child_weight': 43}. Best is trial 21 with value: 450.018009460048.
# [I 2023-11-03 23:48:45,066] Trial 25 finished with value: 458.31975434430296 and parameters: {'lambda': 0.03979517719961696, 'alpha': 0.10031808612803572, 'colsample_bytree': 0.8564612493250015, 'subsample': 0.6487550539569624, 'learning_rate': 0.08617904380085123, 'n_estimators': 432, 'max_depth': 7, 'min_child_weight': 24}. Best is trial 21 with value: 450.018009460048.
# [I 2023-11-03 23:48:45,547] Trial 26 finished with value: 448.36576926337506 and parameters: {'lambda': 0.06188163753796895, 'alpha': 0.24530621070623185, 'colsample_bytree': 0.9439521937849035, 'subsample': 0.8297398385198567, 'learning_rate': 0.0677722233142328, 'n_estimators': 518, 'max_depth': 8, 'min_child_weight': 36}. Best is trial 26 with value: 448.36576926337506.
# [I 2023-11-03 23:48:45,996] Trial 27 finished with value: 452.88123605760484 and parameters: {'lambda': 0.06423654900074313, 'alpha': 0.2293500768117055, 'colsample_bytree': 0.9418257768792154, 'subsample': 0.8288732886289283, 'learning_rate': 0.06705196148260531, 'n_estimators': 546, 'max_depth': 7, 'min_child_weight': 33}. Best is trial 26 with value: 448.36576926337506.
# [I 2023-11-03 23:48:46,704] Trial 28 finished with value: 450.3868552258928 and parameters: {'lambda': 0.05996717547297355, 'alpha': 0.40566380089717113, 'colsample_bytree': 0.9490177259144957, 'subsample': 0.8374192062038438, 'learning_rate': 0.07458611842075308, 'n_estimators': 683, 'max_depth': 8, 'min_child_weight': 44}. Best is trial 26 with value: 448.36576926337506.
# [I 2023-11-03 23:48:47,576] Trial 29 finished with value: 452.03736325416486 and parameters: {'lambda': 0.036418283154438486, 'alpha': 0.25265392492633676, 'colsample_bytree': 0.8406107115097217, 'subsample': 0.7524845347795311, 'learning_rate': 0.06087635007694857, 'n_estimators': 624, 'max_depth': 8, 'min_child_weight': 46}. Best is trial 26 with value: 448.36576926337506.
# [I 2023-11-03 23:48:47,846] Trial 30 finished with value: 461.00497506755505 and parameters: {'lambda': 0.04345203378686538, 'alpha': 0.4230489642770924, 'colsample_bytree': 0.8489523549681046, 'subsample': 0.7639719549424067, 'learning_rate': 0.0674535739895649, 'n_estimators': 302, 'max_depth': 7, 'min_child_weight': 29}. Best is trial 26 with value: 448.36576926337506.
# [I 2023-11-03 23:48:48,480] Trial 31 finished with value: 448.93217384942653 and parameters: {'lambda': 0.0615356641984743, 'alpha': 0.4052248544115088, 'colsample_bytree': 0.9395709937483289, 'subsample': 0.8095765134555074, 'learning_rate': 0.07716907298100363, 'n_estimators': 710, 'max_depth': 8, 'min_child_weight': 44}. Best is trial 26 with value: 448.36576926337506.
# [I 2023-11-03 23:48:49,089] Trial 32 finished with value: 451.57906647986715 and parameters: {'lambda': 0.05975253022357004, 'alpha': 0.2738449774850376, 'colsample_bytree': 0.9377514941275209, 'subsample': 0.9960642528821309, 'learning_rate': 0.07983459218585792, 'n_estimators': 746, 'max_depth': 8, 'min_child_weight': 40}. Best is trial 26 with value: 448.36576926337506.
# [I 2023-11-03 23:48:49,588] Trial 33 finished with value: 452.4717324727244 and parameters: {'lambda': 0.054268047070375344, 'alpha': 0.17952960780425423, 'colsample_bytree': 0.9177587401978587, 'subsample': 0.8121910541138958, 'learning_rate': 0.09238988116754421, 'n_estimators': 536, 'max_depth': 8, 'min_child_weight': 35}. Best is trial 26 with value: 448.36576926337506.
# [I 2023-11-03 23:48:49,767] Trial 34 finished with value: 537.0889913189058 and parameters: {'lambda': 0.0632241625457698, 'alpha': 0.25970495737653965, 'colsample_bytree': 0.8711393016164657, 'subsample': 0.7531893016814446, 'learning_rate': 0.07668832397533373, 'n_estimators': 262, 'max_depth': 4, 'min_child_weight': 43}. Best is trial 26 with value: 448.36576926337506.
# [I 2023-11-03 23:48:50,155] Trial 35 finished with value: 453.78813323545586 and parameters: {'lambda': 0.050599527294194376, 'alpha': 0.41242185225827743, 'colsample_bytree': 0.9584866422763855, 'subsample': 0.8003771234385285, 'learning_rate': 0.08160131916740833, 'n_estimators': 516, 'max_depth': 7, 'min_child_weight': 46}. Best is trial 26 with value: 448.36576926337506.
# [I 2023-11-03 23:48:50,718] Trial 36 finished with value: 447.92301752603606 and parameters: {'lambda': 0.07575813301892925, 'alpha': 0.31986607695230684, 'colsample_bytree': 0.9093574242649306, 'subsample': 0.9076308558827275, 'learning_rate': 0.05818989324717566, 'n_estimators': 599, 'max_depth': 8, 'min_child_weight': 37}. Best is trial 36 with value: 447.92301752603606.
# [I 2023-11-03 23:48:51,191] Trial 37 finished with value: 453.75061250665914 and parameters: {'lambda': 0.07648525395689265, 'alpha': 0.476758248626089, 'colsample_bytree': 0.9609033376372202, 'subsample': 0.9093597179841343, 'learning_rate': 0.056168094302900505, 'n_estimators': 612, 'max_depth': 7, 'min_child_weight': 31}. Best is trial 36 with value: 447.92301752603606.
# [I 2023-11-03 23:48:51,331] Trial 38 finished with value: 466.28081532202646 and parameters: {'lambda': 0.06804218356601734, 'alpha': 0.5844201733174683, 'colsample_bytree': 0.9070392167597424, 'subsample': 0.9561091218921998, 'learning_rate': 0.06289454251098768, 'n_estimators': 102, 'max_depth': 8, 'min_child_weight': 26}. Best is trial 36 with value: 447.92301752603606.
# [I 2023-11-03 23:48:51,650] Trial 39 finished with value: 527.7855211287359 and parameters: {'lambda': 0.07761026741897215, 'alpha': 0.3256253336675058, 'colsample_bytree': 0.7918242069737198, 'subsample': 0.8755183442396703, 'learning_rate': 0.04362815723747441, 'n_estimators': 688, 'max_depth': 4, 'min_child_weight': 18}. Best is trial 36 with value: 447.92301752603606.
# [I 2023-11-03 23:48:52,246] Trial 40 finished with value: 456.1527223910662 and parameters: {'lambda': 0.04446466297366736, 'alpha': 0.35756261012135876, 'colsample_bytree': 0.999571657683621, 'subsample': 0.8571126850080983, 'learning_rate': 0.056256928665042026, 'n_estimators': 750, 'max_depth': 7, 'min_child_weight': 50}. Best is trial 36 with value: 447.92301752603606.
# [I 2023-11-03 23:48:52,779] Trial 41 finished with value: 447.1021523052194 and parameters: {'lambda': 0.056185124017313404, 'alpha': 0.23251817315178794, 'colsample_bytree': 0.9261776252138958, 'subsample': 0.9013604944232184, 'learning_rate': 0.07117295694849461, 'n_estimators': 580, 'max_depth': 8, 'min_child_weight': 37}. Best is trial 41 with value: 447.1021523052194.
# [I 2023-11-03 23:48:53,422] Trial 42 finished with value: 446.02148366293846 and parameters: {'lambda': 0.058239968106010134, 'alpha': 0.206696921619279, 'colsample_bytree': 0.9571500154300894, 'subsample': 0.8901468165934742, 'learning_rate': 0.07135674149538856, 'n_estimators': 579, 'max_depth': 8, 'min_child_weight': 39}. Best is trial 42 with value: 446.02148366293846.
# [I 2023-11-03 23:48:53,988] Trial 43 finished with value: 445.4503584029839 and parameters: {'lambda': 0.05464212184492169, 'alpha': 0.29267427047959105, 'colsample_bytree': 0.9670533735815213, 'subsample': 0.9155298483810665, 'learning_rate': 0.0708107579350137, 'n_estimators': 581, 'max_depth': 8, 'min_child_weight': 42}. Best is trial 43 with value: 445.4503584029839.
# [I 2023-11-03 23:48:54,519] Trial 44 finished with value: 448.382593703971 and parameters: {'lambda': 0.0568532528259744, 'alpha': 0.19115625857247465, 'colsample_bytree': 0.9673757252580983, 'subsample': 0.9169059497364969, 'learning_rate': 0.06324950052909976, 'n_estimators': 577, 'max_depth': 8, 'min_child_weight': 41}. Best is trial 43 with value: 445.4503584029839.
# [I 2023-11-03 23:48:55,591] Trial 45 finished with value: 447.5345241841129 and parameters: {'lambda': 0.05676729822440489, 'alpha': 0.28207674136536537, 'colsample_bytree': 0.978365359133291, 'subsample': 0.9691841408532906, 'learning_rate': 0.06994835459750526, 'n_estimators': 500, 'max_depth': 8, 'min_child_weight': 39}. Best is trial 43 with value: 445.4503584029839.
# [I 2023-11-03 23:48:56,996] Trial 46 finished with value: 448.38059972013417 and parameters: {'lambda': 0.05573593129530934, 'alpha': 0.2052810509128019, 'colsample_bytree': 0.9991244750949283, 'subsample': 0.97284452251548, 'learning_rate': 0.0709476887738763, 'n_estimators': 648, 'max_depth': 8, 'min_child_weight': 39}. Best is trial 43 with value: 445.4503584029839.
# [I 2023-11-03 23:48:57,313] Trial 47 finished with value: 491.2934217579412 and parameters: {'lambda': 0.05197152232030776, 'alpha': 0.31408803286364967, 'colsample_bytree': 0.9795155362286949, 'subsample': 0.9483401859136387, 'learning_rate': 0.05803939138077564, 'n_estimators': 588, 'max_depth': 5, 'min_child_weight': 47}. Best is trial 43 with value: 445.4503584029839.
# [I 2023-11-03 23:48:57,689] Trial 48 finished with value: 456.07775979518885 and parameters: {'lambda': 0.07124681575173986, 'alpha': 0.29509010988816736, 'colsample_bytree': 0.9296946519545273, 'subsample': 0.9055708963142238, 'learning_rate': 0.0639160376749033, 'n_estimators': 501, 'max_depth': 7, 'min_child_weight': 42}. Best is trial 43 with value: 445.4503584029839.
# [I 2023-11-03 23:48:58,373] Trial 49 finished with value: 452.78214346906884 and parameters: {'lambda': 0.05688861669726073, 'alpha': 0.14989461011989827, 'colsample_bytree': 0.969536563108097, 'subsample': 0.9998216917321092, 'learning_rate': 0.07169051942129086, 'n_estimators': 820, 'max_depth': 8, 'min_child_weight': 16}. Best is trial 43 with value: 445.4503584029839.
# [I 2023-11-03 23:48:58,995] Trial 50 finished with value: 447.6566673635241 and parameters: {'lambda': 0.08024230413002716, 'alpha': 0.20777067799866267, 'colsample_bytree': 0.9131710223572641, 'subsample': 0.8959672826913352, 'learning_rate': 0.05866725399780208, 'n_estimators': 668, 'max_depth': 8, 'min_child_weight': 31}. Best is trial 43 with value: 445.4503584029839.
# [I 2023-11-03 23:48:59,638] Trial 51 finished with value: 448.7943981206893 and parameters: {'lambda': 0.07994857004547833, 'alpha': 0.2140751070078691, 'colsample_bytree': 0.9106877572377622, 'subsample': 0.8876642926050897, 'learning_rate': 0.059538905392290606, 'n_estimators': 673, 'max_depth': 8, 'min_child_weight': 34}. Best is trial 43 with value: 445.4503584029839.
# [I 2023-11-03 23:49:00,179] Trial 52 finished with value: 447.74005486890127 and parameters: {'lambda': 0.08186783850078595, 'alpha': 0.2832890127156541, 'colsample_bytree': 0.9745810069982809, 'subsample': 0.9287005281058603, 'learning_rate': 0.053559840292803536, 'n_estimators': 598, 'max_depth': 8, 'min_child_weight': 31}. Best is trial 43 with value: 445.4503584029839.
# [I 2023-11-03 23:49:00,824] Trial 53 finished with value: 446.78601074109224 and parameters: {'lambda': 0.08124005453769667, 'alpha': 0.16554701303329217, 'colsample_bytree': 0.9766662468243155, 'subsample': 0.9392120238976952, 'learning_rate': 0.050447626861998246, 'n_estimators': 729, 'max_depth': 8, 'min_child_weight': 31}. Best is trial 43 with value: 445.4503584029839.
# [I 2023-11-03 23:49:01,731] Trial 54 finished with value: 448.00876098110507 and parameters: {'lambda': 0.07044489741763997, 'alpha': 0.15252486327448714, 'colsample_bytree': 0.9968827249947634, 'subsample': 0.9697967821381479, 'learning_rate': 0.04558015667203287, 'n_estimators': 879, 'max_depth': 8, 'min_child_weight': 26}. Best is trial 43 with value: 445.4503584029839.
# [I 2023-11-03 23:49:02,358] Trial 55 finished with value: 447.29248428552484 and parameters: {'lambda': 0.06641690981635072, 'alpha': 0.18346518201529796, 'colsample_bytree': 0.9611286614647983, 'subsample': 0.9418205332469423, 'learning_rate': 0.07320539823718877, 'n_estimators': 731, 'max_depth': 8, 'min_child_weight': 29}. Best is trial 43 with value: 445.4503584029839.
# [I 2023-11-03 23:49:02,833] Trial 56 finished with value: 463.6287191553056 and parameters: {'lambda': 0.06548599145670614, 'alpha': 0.06149226593864769, 'colsample_bytree': 0.962100250713597, 'subsample': 0.929832044747864, 'learning_rate': 0.07346900300801745, 'n_estimators': 749, 'max_depth': 6, 'min_child_weight': 28}. Best is trial 43 with value: 445.4503584029839.
# [I 2023-11-03 23:49:03,441] Trial 57 finished with value: 453.07595495633615 and parameters: {'lambda': 0.06776377242636301, 'alpha': 0.19621999277812086, 'colsample_bytree': 0.9830948791759035, 'subsample': 0.9463995777587455, 'learning_rate': 0.06990075748035081, 'n_estimators': 846, 'max_depth': 7, 'min_child_weight': 24}. Best is trial 43 with value: 445.4503584029839.
# [I 2023-11-03 23:49:04,184] Trial 58 finished with value: 451.3908705473207 and parameters: {'lambda': 0.050664930522159875, 'alpha': 0.15628265321527632, 'colsample_bytree': 0.9551340509585878, 'subsample': 0.8600752556295096, 'learning_rate': 0.06576213160468691, 'n_estimators': 711, 'max_depth': 8, 'min_child_weight': 4}. Best is trial 43 with value: 445.4503584029839.
# [I 2023-11-03 23:49:04,728] Trial 59 finished with value: 455.691023988222 and parameters: {'lambda': 0.05816505678886125, 'alpha': 0.07078906704727853, 'colsample_bytree': 0.9282278000696421, 'subsample': 0.974433792384687, 'learning_rate': 0.07305423746850213, 'n_estimators': 780, 'max_depth': 7, 'min_child_weight': 33}. Best is trial 43 with value: 445.4503584029839.
# [I 2023-11-03 23:49:05,170] Trial 60 finished with value: 448.42501991397455 and parameters: {'lambda': 0.06553344230526857, 'alpha': 0.2693080967910597, 'colsample_bytree': 0.8854780156572132, 'subsample': 0.9343153095098107, 'learning_rate': 0.06394087137235056, 'n_estimators': 439, 'max_depth': 8, 'min_child_weight': 22}. Best is trial 43 with value: 445.4503584029839.
# [I 2023-11-03 23:49:05,755] Trial 61 finished with value: 446.62163603481054 and parameters: {'lambda': 0.08531592709877911, 'alpha': 0.22121448204635288, 'colsample_bytree': 0.9237127339314823, 'subsample': 0.8868329447687955, 'learning_rate': 0.06838979943084562, 'n_estimators': 650, 'max_depth': 8, 'min_child_weight': 31}. Best is trial 43 with value: 445.4503584029839.
# [I 2023-11-03 23:49:06,475] Trial 62 finished with value: 449.2003191981021 and parameters: {'lambda': 0.094466941566145, 'alpha': 0.23084923591152906, 'colsample_bytree': 0.9807034258891562, 'subsample': 0.9564606404141144, 'learning_rate': 0.07040535198872361, 'n_estimators': 653, 'max_depth': 8, 'min_child_weight': 38}. Best is trial 43 with value: 445.4503584029839.
# [I 2023-11-03 23:49:06,991] Trial 63 finished with value: 445.77806435482296 and parameters: {'lambda': 0.08344032164235221, 'alpha': 0.15139574637786457, 'colsample_bytree': 0.9504915693341728, 'subsample': 0.8854672140995528, 'learning_rate': 0.07407504716761668, 'n_estimators': 564, 'max_depth': 8, 'min_child_weight': 29}. Best is trial 43 with value: 445.4503584029839.
# [I 2023-11-03 23:49:07,514] Trial 64 finished with value: 447.4086520576317 and parameters: {'lambda': 0.08410347726612291, 'alpha': 0.17745231601346798, 'colsample_bytree': 0.9472210530174944, 'subsample': 0.8952271630006428, 'learning_rate': 0.07620746603336008, 'n_estimators': 564, 'max_depth': 8, 'min_child_weight': 27}. Best is trial 43 with value: 445.4503584029839.
# [I 2023-11-03 23:49:08,207] Trial 65 finished with value: 447.09505896491606 and parameters: {'lambda': 0.0886519924824433, 'alpha': 0.14513050981465475, 'colsample_bytree': 0.8955101182150005, 'subsample': 0.8736613400617436, 'learning_rate': 0.08385958718193093, 'n_estimators': 734, 'max_depth': 8, 'min_child_weight': 23}. Best is trial 43 with value: 445.4503584029839.
# [I 2023-11-03 23:49:08,788] Trial 66 finished with value: 447.9146887905591 and parameters: {'lambda': 0.08997807138402969, 'alpha': 0.12889206636892941, 'colsample_bytree': 0.8768259597715388, 'subsample': 0.8738253950730623, 'learning_rate': 0.08310775956530425, 'n_estimators': 635, 'max_depth': 8, 'min_child_weight': 23}. Best is trial 43 with value: 445.4503584029839.
# [I 2023-11-03 23:49:09,536] Trial 67 finished with value: 447.81006741863393 and parameters: {'lambda': 0.08922301018217778, 'alpha': 0.04518949425570336, 'colsample_bytree': 0.9198947900770902, 'subsample': 0.8530243811567133, 'learning_rate': 0.07916925770899086, 'n_estimators': 788, 'max_depth': 8, 'min_child_weight': 21}. Best is trial 43 with value: 445.4503584029839.
# [I 2023-11-03 23:49:10,147] Trial 68 finished with value: 450.84021895822804 and parameters: {'lambda': 0.0854478597227142, 'alpha': 0.09502460854704409, 'colsample_bytree': 0.86667077186662, 'subsample': 0.8880101509513427, 'learning_rate': 0.08429249323337054, 'n_estimators': 629, 'max_depth': 8, 'min_child_weight': 15}. Best is trial 43 with value: 445.4503584029839.
# [I 2023-11-03 23:49:10,698] Trial 69 finished with value: 453.22731427030453 and parameters: {'lambda': 0.09281389697377623, 'alpha': 0.13775339650160545, 'colsample_bytree': 0.9001337456757266, 'subsample': 0.8439477424517182, 'learning_rate': 0.09029559933065982, 'n_estimators': 709, 'max_depth': 7, 'min_child_weight': 32}. Best is trial 43 with value: 445.4503584029839.
# [I 2023-11-03 23:49:11,141] Trial 70 finished with value: 445.9026179525858 and parameters: {'lambda': 0.08419017850179804, 'alpha': 0.22454183476147205, 'colsample_bytree': 0.9311934089353041, 'subsample': 0.8654312877095802, 'learning_rate': 0.07992136107556319, 'n_estimators': 475, 'max_depth': 8, 'min_child_weight': 35}. Best is trial 43 with value: 445.4503584029839.
# [I 2023-11-03 23:49:11,796] Trial 71 finished with value: 447.2770492146995 and parameters: {'lambda': 0.08336671362173191, 'alpha': 0.22820397961144537, 'colsample_bytree': 0.9292655355476982, 'subsample': 0.8790599862030049, 'learning_rate': 0.07843503943597774, 'n_estimators': 473, 'max_depth': 8, 'min_child_weight': 35}. Best is trial 43 with value: 445.4503584029839.
# [I 2023-11-03 23:49:12,432] Trial 72 finished with value: 446.77382845000983 and parameters: {'lambda': 0.0863938514205246, 'alpha': 0.1552905597969132, 'colsample_bytree': 0.894340439418549, 'subsample': 0.9198573929209147, 'learning_rate': 0.08182880423368377, 'n_estimators': 556, 'max_depth': 8, 'min_child_weight': 29}. Best is trial 43 with value: 445.4503584029839.
# [I 2023-11-03 23:49:12,941] Trial 73 finished with value: 448.5176012559191 and parameters: {'lambda': 0.08692447850874849, 'alpha': 0.16804432656209478, 'colsample_bytree': 0.8934251508139471, 'subsample': 0.9184599051353948, 'learning_rate': 0.08185047158289274, 'n_estimators': 556, 'max_depth': 8, 'min_child_weight': 29}. Best is trial 43 with value: 445.4503584029839.
# [I 2023-11-03 23:49:13,650] Trial 74 finished with value: 448.7266586972399 and parameters: {'lambda': 0.08516149302874827, 'alpha': 0.10023387292001305, 'colsample_bytree': 0.8547937575221433, 'subsample': 0.8598125315415006, 'learning_rate': 0.08880649735553581, 'n_estimators': 540, 'max_depth': 8, 'min_child_weight': 30}. Best is trial 43 with value: 445.4503584029839.
# [I 2023-11-03 23:49:14,690] Trial 75 finished with value: 446.1027838638129 and parameters: {'lambda': 0.08008345615421715, 'alpha': 0.13482424743369742, 'colsample_bytree': 0.9465002163916496, 'subsample': 0.8668131569998785, 'learning_rate': 0.07527826967455913, 'n_estimators': 479, 'max_depth': 8, 'min_child_weight': 25}. Best is trial 43 with value: 445.4503584029839.
# [I 2023-11-03 23:49:15,397] Trial 76 finished with value: 447.558483660288 and parameters: {'lambda': 0.07879368700686103, 'alpha': 0.12029092677387744, 'colsample_bytree': 0.9561322285029681, 'subsample': 0.8308030435617406, 'learning_rate': 0.0753166930581586, 'n_estimators': 461, 'max_depth': 8, 'min_child_weight': 25}. Best is trial 43 with value: 445.4503584029839.
# [I 2023-11-03 23:49:15,778] Trial 77 finished with value: 446.8916236812884 and parameters: {'lambda': 0.08079940127340696, 'alpha': 0.2606937019521698, 'colsample_bytree': 0.9446029091528922, 'subsample': 0.9182969569354986, 'learning_rate': 0.08000680467246234, 'n_estimators': 418, 'max_depth': 8, 'min_child_weight': 27}. Best is trial 43 with value: 445.4503584029839.
# [I 2023-11-03 23:49:16,556] Trial 78 finished with value: 450.83461500219244 and parameters: {'lambda': 0.07551541455198577, 'alpha': 0.167152310126641, 'colsample_bytree': 0.8296283198717361, 'subsample': 0.8485210212158674, 'learning_rate': 0.06710880737689444, 'n_estimators': 512, 'max_depth': 8, 'min_child_weight': 34}. Best is trial 43 with value: 445.4503584029839.
# [I 2023-11-03 23:49:16,942] Trial 79 finished with value: 453.52803862405443 and parameters: {'lambda': 0.07339209109276736, 'alpha': 0.2097058319528781, 'colsample_bytree': 0.943358151035, 'subsample': 0.8925127054388712, 'learning_rate': 0.07508469125538385, 'n_estimators': 485, 'max_depth': 7, 'min_child_weight': 32}. Best is trial 43 with value: 445.4503584029839.
# [I 2023-11-03 23:49:17,359] Trial 80 finished with value: 462.6402770251699 and parameters: {'lambda': 0.08294550873004584, 'alpha': 0.24812154199240827, 'colsample_bytree': 0.9865466738987296, 'subsample': 0.8694954012003868, 'learning_rate': 0.07784466224159677, 'n_estimators': 612, 'max_depth': 6, 'min_child_weight': 30}. Best is trial 43 with value: 445.4503584029839.
# [I 2023-11-03 23:49:18,129] Trial 81 finished with value: 446.60178567301983 and parameters: {'lambda': 0.08139161598268542, 'alpha': 0.2667315325646061, 'colsample_bytree': 0.94307661021021, 'subsample': 0.916709575183931, 'learning_rate': 0.08117990414546011, 'n_estimators': 410, 'max_depth': 8, 'min_child_weight': 26}. Best is trial 43 with value: 445.4503584029839.
# [I 2023-11-03 23:49:18,475] Trial 82 finished with value: 446.8716616507831 and parameters: {'lambda': 0.07860148548353013, 'alpha': 0.1871380836276912, 'colsample_bytree': 0.9250197346500793, 'subsample': 0.9226319514949669, 'learning_rate': 0.0846476479125417, 'n_estimators': 385, 'max_depth': 8, 'min_child_weight': 28}. Best is trial 43 with value: 445.4503584029839.
# [I 2023-11-03 23:49:18,842] Trial 83 finished with value: 446.7755817572682 and parameters: {'lambda': 0.08172712120076324, 'alpha': 0.2183541776920782, 'colsample_bytree': 0.9511019827064026, 'subsample': 0.8978910176556334, 'learning_rate': 0.08709081158115704, 'n_estimators': 406, 'max_depth': 8, 'min_child_weight': 25}. Best is trial 43 with value: 445.4503584029839.
# [I 2023-11-03 23:49:19,390] Trial 84 finished with value: 448.22328922465306 and parameters: {'lambda': 0.08650414653010648, 'alpha': 0.30072945871650436, 'colsample_bytree': 0.9415507906001054, 'subsample': 0.9068510327455198, 'learning_rate': 0.08774804060364699, 'n_estimators': 298, 'max_depth': 8, 'min_child_weight': 25}. Best is trial 43 with value: 445.4503584029839.
# [I 2023-11-03 23:49:19,719] Trial 85 finished with value: 445.9182901212356 and parameters: {'lambda': 0.09154109994387384, 'alpha': 0.21226935044336537, 'colsample_bytree': 0.9115523266955541, 'subsample': 0.8783106606508857, 'learning_rate': 0.08226432316469887, 'n_estimators': 345, 'max_depth': 8, 'min_child_weight': 21}. Best is trial 43 with value: 445.4503584029839.
# [I 2023-11-03 23:49:20,147] Trial 86 finished with value: 447.3414137861769 and parameters: {'lambda': 0.09216927729134071, 'alpha': 0.25958535476981115, 'colsample_bytree': 0.9053115840552485, 'subsample': 0.8428183266015155, 'learning_rate': 0.08129938875171948, 'n_estimators': 447, 'max_depth': 8, 'min_child_weight': 20}. Best is trial 43 with value: 445.4503584029839.
# [I 2023-11-03 23:49:20,480] Trial 87 finished with value: 445.57733129613223 and parameters: {'lambda': 0.09910745575637173, 'alpha': 0.13378500420058168, 'colsample_bytree': 0.8798627953090974, 'subsample': 0.8704262526553701, 'learning_rate': 0.07801897514154754, 'n_estimators': 343, 'max_depth': 8, 'min_child_weight': 18}. Best is trial 43 with value: 445.4503584029839.
# [I 2023-11-03 23:49:20,922] Trial 88 finished with value: 493.24528416755834 and parameters: {'lambda': 0.0994177493608019, 'alpha': 0.342226545477742, 'colsample_bytree': 0.9192402143526249, 'subsample': 0.8265101674384411, 'learning_rate': 0.07514587476205026, 'n_estimators': 351, 'max_depth': 5, 'min_child_weight': 18}. Best is trial 43 with value: 445.4503584029839.
# [I 2023-11-03 23:49:21,229] Trial 89 finished with value: 447.01224683620114 and parameters: {'lambda': 0.09866653334033901, 'alpha': 0.23952110028389378, 'colsample_bytree': 0.879747000575906, 'subsample': 0.8634755392268065, 'learning_rate': 0.07833672375856562, 'n_estimators': 317, 'max_depth': 8, 'min_child_weight': 17}. Best is trial 43 with value: 445.4503584029839.
# [I 2023-11-03 23:49:21,439] Trial 90 finished with value: 450.4046162620543 and parameters: {'lambda': 0.09667136570965726, 'alpha': 0.20227661829907617, 'colsample_bytree': 0.936445376679271, 'subsample': 0.803657918664549, 'learning_rate': 0.06871105609436783, 'n_estimators': 205, 'max_depth': 8, 'min_child_weight': 21}. Best is trial 43 with value: 445.4503584029839.
# [I 2023-11-03 23:49:21,693] Trial 91 finished with value: 446.38643516010825 and parameters: {'lambda': 0.09045613121282874, 'alpha': 0.13859194849748546, 'colsample_bytree': 0.9074584401012318, 'subsample': 0.8741359812475825, 'learning_rate': 0.08173732213834148, 'n_estimators': 251, 'max_depth': 8, 'min_child_weight': 20}. Best is trial 43 with value: 445.4503584029839.
# [I 2023-11-03 23:49:22,028] Trial 92 finished with value: 445.1420363115379 and parameters: {'lambda': 0.09135116027995632, 'alpha': 0.12182828307711621, 'colsample_bytree': 0.905615071884123, 'subsample': 0.8818141024894794, 'learning_rate': 0.07238922171425428, 'n_estimators': 268, 'max_depth': 8, 'min_child_weight': 12}. Best is trial 92 with value: 445.1420363115379.
# [I 2023-11-03 23:49:22,431] Trial 93 finished with value: 447.27181314235514 and parameters: {'lambda': 0.0903891446539454, 'alpha': 0.12776344907401085, 'colsample_bytree': 0.9655601591862631, 'subsample': 0.8782583206926585, 'learning_rate': 0.07281673534621072, 'n_estimators': 327, 'max_depth': 8, 'min_child_weight': 7}. Best is trial 92 with value: 445.1420363115379.
# [I 2023-11-03 23:49:22,779] Trial 94 finished with value: 451.1726590408524 and parameters: {'lambda': 0.09544356464281446, 'alpha': 0.03513085732722496, 'colsample_bytree': 0.8664231211665346, 'subsample': 0.8491635606827296, 'learning_rate': 0.0767256856482092, 'n_estimators': 284, 'max_depth': 8, 'min_child_weight': 14}. Best is trial 92 with value: 445.1420363115379.
# [I 2023-11-03 23:49:22,985] Trial 95 finished with value: 450.5866586494344 and parameters: {'lambda': 0.0925093355569615, 'alpha': 0.08605435154691815, 'colsample_bytree': 0.9118923507071663, 'subsample': 0.9089931945208523, 'learning_rate': 0.0808350729699572, 'n_estimators': 160, 'max_depth': 8, 'min_child_weight': 10}. Best is trial 92 with value: 445.1420363115379.
# [I 2023-11-03 23:49:23,353] Trial 96 finished with value: 447.8159611950093 and parameters: {'lambda': 0.09119680822007346, 'alpha': 0.11050463804295142, 'colsample_bytree': 0.8845605610428026, 'subsample': 0.8213829407216704, 'learning_rate': 0.08546617767792015, 'n_estimators': 235, 'max_depth': 8, 'min_child_weight': 19}. Best is trial 92 with value: 445.1420363115379.
# [I 2023-11-03 23:49:23,937] Trial 97 finished with value: 448.4062791282211 and parameters: {'lambda': 0.08793853413620877, 'alpha': 0.13173125367592692, 'colsample_bytree': 0.9679002043831193, 'subsample': 0.8660687293937036, 'learning_rate': 0.07386143637880435, 'n_estimators': 256, 'max_depth': 8, 'min_child_weight': 21}. Best is trial 92 with value: 445.1420363115379.
# [I 2023-11-03 23:49:24,491] Trial 98 finished with value: 444.07769694719633 and parameters: {'lambda': 0.09410017745205176, 'alpha': 0.07490360280681835, 'colsample_bytree': 0.9055519779377318, 'subsample': 0.8347668015697688, 'learning_rate': 0.0911273875573099, 'n_estimators': 371, 'max_depth': 8, 'min_child_weight': 12}. Best is trial 98 with value: 444.07769694719633.
# [I 2023-11-03 23:49:25,227] Trial 99 finished with value: 448.4680844959291 and parameters: {'lambda': 0.09522591100822685, 'alpha': 0.07774356433450165, 'colsample_bytree': 0.9030633842077457, 'subsample': 0.8344356544651631, 'learning_rate': 0.09622144515165061, 'n_estimators': 364, 'max_depth': 8, 'min_child_weight': 14}. Best is trial 98 with value: 444.07769694719633.
# [I 2023-11-03 23:49:25,572] Trial 100 finished with value: 457.13195790277774 and parameters: {'lambda': 0.09732133557778896, 'alpha': 0.05523932875058919, 'colsample_bytree': 0.8525960995992315, 'subsample': 0.8840127986968574, 'learning_rate': 0.09133151115516853, 'n_estimators': 369, 'max_depth': 7, 'min_child_weight': 14}. Best is trial 98 with value: 444.07769694719633.
# [I 2023-11-03 23:49:26,073] Trial 101 finished with value: 451.6829590971089 and parameters: {'lambda': 0.09401193504466691, 'alpha': 0.11112082054904138, 'colsample_bytree': 0.9350868818906894, 'subsample': 0.8996084748904456, 'learning_rate': 0.08887243160833316, 'n_estimators': 332, 'max_depth': 8, 'min_child_weight': 8}. Best is trial 98 with value: 444.07769694719633.
# [I 2023-11-03 23:49:26,360] Trial 102 finished with value: 450.1546579537316 and parameters: {'lambda': 0.0903044393104939, 'alpha': 0.08222304305049896, 'colsample_bytree': 0.9508571334257165, 'subsample': 0.8648972902489525, 'learning_rate': 0.09396490593042281, 'n_estimators': 270, 'max_depth': 8, 'min_child_weight': 13}. Best is trial 98 with value: 444.07769694719633.
# [I 2023-11-03 23:49:27,058] Trial 103 finished with value: 449.610931413444 and parameters: {'lambda': 0.09337618371012102, 'alpha': 0.1806075546038481, 'colsample_bytree': 0.989298410488128, 'subsample': 0.8548373072987283, 'learning_rate': 0.08304452961498306, 'n_estimators': 413, 'max_depth': 8, 'min_child_weight': 12}. Best is trial 98 with value: 444.07769694719633.
# [I 2023-11-03 23:49:27,269] Trial 104 finished with value: 447.7681373188358 and parameters: {'lambda': 0.09710476836079934, 'alpha': 0.13798680587680104, 'colsample_bytree': 0.9178626772601842, 'subsample': 0.880768408691096, 'learning_rate': 0.07879422654437855, 'n_estimators': 189, 'max_depth': 8, 'min_child_weight': 16}. Best is trial 98 with value: 444.07769694719633.
# [I 2023-11-03 23:49:27,530] Trial 105 finished with value: 448.4183259342442 and parameters: {'lambda': 0.08773774985746853, 'alpha': 0.18871099391008092, 'colsample_bytree': 0.9027109871431649, 'subsample': 0.8405827401955303, 'learning_rate': 0.07133801333883043, 'n_estimators': 217, 'max_depth': 8, 'min_child_weight': 8}. Best is trial 98 with value: 444.07769694719633.
# [I 2023-11-03 23:49:27,949] Trial 106 finished with value: 445.3694026288512 and parameters: {'lambda': 0.09203228838939284, 'alpha': 0.15022758758732677, 'colsample_bytree': 0.9323301601466638, 'subsample': 0.8148602820400069, 'learning_rate': 0.08587006644550073, 'n_estimators': 394, 'max_depth': 8, 'min_child_weight': 19}. Best is trial 98 with value: 444.07769694719633.
# [I 2023-11-03 23:49:28,275] Trial 107 finished with value: 447.8598915861773 and parameters: {'lambda': 0.09114022085520965, 'alpha': 0.10324183054052372, 'colsample_bytree': 0.9592361175105026, 'subsample': 0.8730066267448382, 'learning_rate': 0.08590524160704417, 'n_estimators': 307, 'max_depth': 8, 'min_child_weight': 19}. Best is trial 98 with value: 444.07769694719633.
# [I 2023-11-03 23:49:28,940] Trial 108 finished with value: 514.8627728976187 and parameters: {'lambda': 0.09942310781594722, 'alpha': 0.018687915648759046, 'colsample_bytree': 0.8795567211215963, 'subsample': 0.8151327584877975, 'learning_rate': 0.07723369261142946, 'n_estimators': 528, 'max_depth': 4, 'min_child_weight': 11}. Best is trial 98 with value: 444.07769694719633.
# [I 2023-11-03 23:49:29,295] Trial 109 finished with value: 447.1767821510297 and parameters: {'lambda': 0.09389635115190689, 'alpha': 0.15469601002983538, 'colsample_bytree': 0.9332088098752351, 'subsample': 0.7931399380161821, 'learning_rate': 0.07477709315709397, 'n_estimators': 347, 'max_depth': 8, 'min_child_weight': 22}. Best is trial 98 with value: 444.07769694719633.
# [I 2023-11-03 23:49:29,688] Trial 110 finished with value: 447.18412125170914 and parameters: {'lambda': 0.0885296923546582, 'alpha': 0.0764171366094647, 'colsample_bytree': 0.9747150859258888, 'subsample': 0.8187650053120982, 'learning_rate': 0.08276032091433996, 'n_estimators': 389, 'max_depth': 8, 'min_child_weight': 17}. Best is trial 98 with value: 444.07769694719633.
# [I 2023-11-03 23:49:30,062] Trial 111 finished with value: 450.0935704251363 and parameters: {'lambda': 0.08345701740116027, 'alpha': 0.16802498541098915, 'colsample_bytree': 0.917010205624692, 'subsample': 0.8951869804688886, 'learning_rate': 0.08107514708137811, 'n_estimators': 423, 'max_depth': 8, 'min_child_weight': 45}. Best is trial 98 with value: 444.07769694719633.
# [I 2023-11-03 23:49:30,964] Trial 112 finished with value: 448.71876470455277 and parameters: {'lambda': 0.09527881908044397, 'alpha': 0.13678597249996105, 'colsample_bytree': 0.936297863241321, 'subsample': 0.9093461757268094, 'learning_rate': 0.07957482938244018, 'n_estimators': 490, 'max_depth': 8, 'min_child_weight': 20}. Best is trial 98 with value: 444.07769694719633.
# [I 2023-11-03 23:49:31,525] Trial 113 finished with value: 449.9557434279188 and parameters: {'lambda': 0.09179267556391965, 'alpha': 0.198340286322593, 'colsample_bytree': 0.9518586089349943, 'subsample': 0.8518862248268706, 'learning_rate': 0.08424110846712184, 'n_estimators': 393, 'max_depth': 8, 'min_child_weight': 2}. Best is trial 98 with value: 444.07769694719633.
# [I 2023-11-03 23:49:31,788] Trial 114 finished with value: 450.67806069736673 and parameters: {'lambda': 0.08484974316210503, 'alpha': 0.05915595607674217, 'colsample_bytree': 0.9101982775417267, 'subsample': 0.9362035776777874, 'learning_rate': 0.07195722687011363, 'n_estimators': 277, 'max_depth': 8, 'min_child_weight': 40}. Best is trial 98 with value: 444.07769694719633.
# [I 2023-11-03 23:49:32,055] Trial 115 finished with value: 447.80899701931827 and parameters: {'lambda': 0.0900507242351951, 'alpha': 0.2827189807894806, 'colsample_bytree': 0.8855353522999816, 'subsample': 0.8850005219173102, 'learning_rate': 0.07654245642946568, 'n_estimators': 248, 'max_depth': 8, 'min_child_weight': 24}. Best is trial 98 with value: 444.07769694719633.
# [I 2023-11-03 23:49:32,511] Trial 116 finished with value: 446.35059938993874 and parameters: {'lambda': 0.07728964160159398, 'alpha': 0.11526989758640226, 'colsample_bytree': 0.9273894960930716, 'subsample': 0.8348046307048139, 'learning_rate': 0.08947312796875682, 'n_estimators': 462, 'max_depth': 8, 'min_child_weight': 22}. Best is trial 98 with value: 444.07769694719633.
# [I 2023-11-03 23:49:33,019] Trial 117 finished with value: 445.4233658348536 and parameters: {'lambda': 0.07814496304161561, 'alpha': 0.11817340383721671, 'colsample_bytree': 0.897897012550824, 'subsample': 0.8402878313182705, 'learning_rate': 0.08878854016541281, 'n_estimators': 454, 'max_depth': 8, 'min_child_weight': 22}. Best is trial 98 with value: 444.07769694719633.
# [I 2023-11-03 23:49:33,458] Trial 118 finished with value: 446.5238219502108 and parameters: {'lambda': 0.07919098089098042, 'alpha': 0.09660952772935785, 'colsample_bytree': 0.8720488374043859, 'subsample': 0.8360350655214069, 'learning_rate': 0.09000578836008258, 'n_estimators': 455, 'max_depth': 8, 'min_child_weight': 24}. Best is trial 98 with value: 444.07769694719633.
# [I 2023-11-03 23:49:33,910] Trial 119 finished with value: 449.8125141607589 and parameters: {'lambda': 0.07370234526778464, 'alpha': 0.03308060616513765, 'colsample_bytree': 0.8928796369660826, 'subsample': 0.7990921023458428, 'learning_rate': 0.09981144699314229, 'n_estimators': 473, 'max_depth': 8, 'min_child_weight': 23}. Best is trial 98 with value: 444.07769694719633.
# [I 2023-11-03 23:49:34,391] Trial 120 finished with value: 448.51112467388026 and parameters: {'lambda': 0.07830831076434883, 'alpha': 0.11644925069095882, 'colsample_bytree': 0.9691922465455869, 'subsample': 0.8092374884804702, 'learning_rate': 0.08788124787862261, 'n_estimators': 507, 'max_depth': 8, 'min_child_weight': 18}. Best is trial 98 with value: 444.07769694719633.
# [I 2023-11-03 23:49:34,832] Trial 121 finished with value: 447.71533473804084 and parameters: {'lambda': 0.07640988062746464, 'alpha': 0.1509806841816763, 'colsample_bytree': 0.9257622277259036, 'subsample': 0.8651852314293382, 'learning_rate': 0.09290646242490541, 'n_estimators': 434, 'max_depth': 8, 'min_child_weight': 20}. Best is trial 98 with value: 444.07769694719633.
# [I 2023-11-03 23:49:35,675] Trial 122 finished with value: 453.45962135415454 and parameters: {'lambda': 0.0871854038097702, 'alpha': 0.16882079128805574, 'colsample_bytree': 0.902667554046883, 'subsample': 0.8268355484517083, 'learning_rate': 0.08606549032440869, 'n_estimators': 962, 'max_depth': 8, 'min_child_weight': 22}. Best is trial 98 with value: 444.07769694719633.
# [I 2023-11-03 23:49:36,204] Trial 123 finished with value: 448.8673562817345 and parameters: {'lambda': 0.08341758649417383, 'alpha': 0.11584143591110833, 'colsample_bytree': 0.9216524672742956, 'subsample': 0.8504194010468346, 'learning_rate': 0.09403612160260902, 'n_estimators': 569, 'max_depth': 8, 'min_child_weight': 22}. Best is trial 98 with value: 444.07769694719633.
# [I 2023-11-03 23:49:36,664] Trial 124 finished with value: 448.88462791131997 and parameters: {'lambda': 0.08549542868294226, 'alpha': 0.06079786206792967, 'colsample_bytree': 0.9540566793699015, 'subsample': 0.8378513080026949, 'learning_rate': 0.089571043407978, 'n_estimators': 522, 'max_depth': 8, 'min_child_weight': 42}. Best is trial 98 with value: 444.07769694719633.
# [I 2023-11-03 23:49:37,019] Trial 125 finished with value: 449.2765123081603 and parameters: {'lambda': 0.08892850067485725, 'alpha': 0.14254228550916093, 'colsample_bytree': 0.9901830530806819, 'subsample': 0.7825659971116691, 'learning_rate': 0.09143416702932587, 'n_estimators': 372, 'max_depth': 8, 'min_child_weight': 20}. Best is trial 98 with value: 444.07769694719633.
# [I 2023-11-03 23:49:37,448] Trial 126 finished with value: 450.3009493100086 and parameters: {'lambda': 0.09736910205045522, 'alpha': 0.19717174525177955, 'colsample_bytree': 0.8404887365623847, 'subsample': 0.8584263576013424, 'learning_rate': 0.08305809524890546, 'n_estimators': 448, 'max_depth': 8, 'min_child_weight': 16}. Best is trial 98 with value: 444.07769694719633.
# ...
# [I 2023-11-03 23:49:48,408] Trial 159 finished with value: 447.3847973527452 and parameters: {'lambda': 0.07240242457650184, 'alpha': 0.022408936758379877, 'colsample_bytree': 0.865389492076438, 'subsample': 0.918286600532049, 'learning_rate': 0.0748580322042022, 'n_estimators': 319, 'max_depth': 8, 'min_child_weight': 16}. Best is trial 155 with value: 442.96497684023586.
# [I 2023-11-03 23:49:48,740] Trial 160 finished with value: 445.4881058356973 and parameters: {'lambda': 0.06760031064724609, 'alpha': 0.09861805255705411, 'colsample_bytree': 0.8730591050066181, 'subsample': 0.9292018815513132, 'learning_rate': 0.07118706566027556, 'n_estimators': 342, 'max_depth': 8, 'min_child_weight': 14}. Best is trial 155 with value: 442.96497684023586.
# [I 2023-11-03 23:49:49,073] Trial 161 finished with value: 444.464260038058 and parameters: {'lambda': 0.0675297093938281, 'alpha': 0.09990995119096986, 'colsample_bytree': 0.877430556955889, 'subsample': 0.9271746793561747, 'learning_rate': 0.0712739841215571, 'n_estimators': 345, 'max_depth': 8, 'min_child_weight': 14}. Best is trial 155 with value: 442.96497684023586.
# [I 2023-11-03 23:49:49,683] Trial 162 finished with value: 449.60906962406295 and parameters: {'lambda': 0.06657701744069865, 'alpha': 0.10109708040146886, 'colsample_bytree': 0.8567578375461536, 'subsample': 0.9301443502069476, 'learning_rate': 0.07106236347089047, 'n_estimators': 345, 'max_depth': 8, 'min_child_weight': 11}. Best is trial 155 with value: 442.96497684023586.
# [I 2023-11-03 23:49:50,038] Trial 163 finished with value: 446.235043605289 and parameters: {'lambda': 0.06272511764033935, 'alpha': 0.11548357605102616, 'colsample_bytree': 0.8742567530319985, 'subsample': 0.88437576698844, 'learning_rate': 0.06860567494872348, 'n_estimators': 361, 'max_depth': 8, 'min_child_weight': 14}. Best is trial 155 with value: 442.96497684023586.
# [I 2023-11-03 23:49:50,400] Trial 164 finished with value: 447.03514331679713 and parameters: {'lambda': 0.06836337619866756, 'alpha': 0.08335551264064794, 'colsample_bytree': 0.9162352599562611, 'subsample': 0.8976140993875811, 'learning_rate': 0.07116842703320687, 'n_estimators': 333, 'max_depth': 8, 'min_child_weight': 17}. Best is trial 155 with value: 442.96497684023586.
# [I 2023-11-03 23:49:50,795] Trial 165 finished with value: 446.85432898201435 and parameters: {'lambda': 0.0645965707215684, 'alpha': 0.05967581903628348, 'colsample_bytree': 0.9008116491122069, 'subsample': 0.9131302590349174, 'learning_rate': 0.07934595412787093, 'n_estimators': 379, 'max_depth': 8, 'min_child_weight': 12}. Best is trial 155 with value: 442.96497684023586.
# [I 2023-11-03 23:49:51,058] Trial 166 finished with value: 446.7935519121813 and parameters: {'lambda': 0.07082365781306872, 'alpha': 0.10026489794557138, 'colsample_bytree': 0.8747736055630246, 'subsample': 0.930882313584196, 'learning_rate': 0.0652272526632949, 'n_estimators': 260, 'max_depth': 8, 'min_child_weight': 13}. Best is trial 155 with value: 442.96497684023586.
# [I 2023-11-03 23:49:51,394] Trial 167 finished with value: 445.3131861445479 and parameters: {'lambda': 0.06091377454078051, 'alpha': 0.12359670277550625, 'colsample_bytree': 0.8497913448278229, 'subsample': 0.8802787192191998, 'learning_rate': 0.06831967740928171, 'n_estimators': 355, 'max_depth': 8, 'min_child_weight': 19}. Best is trial 155 with value: 442.96497684023586.
# [I 2023-11-03 23:49:51,985] Trial 168 finished with value: 443.96427970032863 and parameters: {'lambda': 0.06140969700640401, 'alpha': 0.12760845649801134, 'colsample_bytree': 0.8499895467648751, 'subsample': 0.8748663887040588, 'learning_rate': 0.06748653866962065, 'n_estimators': 421, 'max_depth': 8, 'min_child_weight': 19}. Best is trial 155 with value: 442.96497684023586.
# [I 2023-11-03 23:49:52,371] Trial 169 finished with value: 445.747855678242 and parameters: {'lambda': 0.06227858017959972, 'alpha': 0.1239172041465858, 'colsample_bytree': 0.8399445407138881, 'subsample': 0.8760722065230737, 'learning_rate': 0.06280662565970808, 'n_estimators': 399, 'max_depth': 8, 'min_child_weight': 18}. Best is trial 155 with value: 442.96497684023586.
# [I 2023-11-03 23:49:52,781] Trial 170 finished with value: 446.08204777839734 and parameters: {'lambda': 0.05795287401039084, 'alpha': 0.10089667089174133, 'colsample_bytree': 0.8189699540181845, 'subsample': 0.8774172848702858, 'learning_rate': 0.06792688606237234, 'n_estimators': 422, 'max_depth': 8, 'min_child_weight': 19}. Best is trial 155 with value: 442.96497684023586.
# [I 2023-11-03 23:49:53,181] Trial 171 finished with value: 445.4809098911435 and parameters: {'lambda': 0.06195615639825301, 'alpha': 0.11647686042813332, 'colsample_bytree': 0.8460324649413047, 'subsample': 0.8692104994524229, 'learning_rate': 0.06515211314381779, 'n_estimators': 407, 'max_depth': 8, 'min_child_weight': 19}. Best is trial 155 with value: 442.96497684023586.
# [I 2023-11-03 23:49:53,550] Trial 172 finished with value: 446.304039348425 and parameters: {'lambda': 0.059779417289826, 'alpha': 0.12711962656437534, 'colsample_bytree': 0.8044852175804773, 'subsample': 0.862773773226043, 'learning_rate': 0.06381159278213444, 'n_estimators': 373, 'max_depth': 8, 'min_child_weight': 19}. Best is trial 155 with value: 442.96497684023586.
# [I 2023-11-03 23:49:53,974] Trial 173 finished with value: 445.8099913647892 and parameters: {'lambda': 0.06090363102432094, 'alpha': 0.08336675068626105, 'colsample_bytree': 0.8531055264557946, 'subsample': 0.891940036147386, 'learning_rate': 0.0659199899305759, 'n_estimators': 409, 'max_depth': 8, 'min_child_weight': 17}. Best is trial 155 with value: 442.96497684023586.
# [I 2023-11-03 23:49:54,380] Trial 174 finished with value: 446.19157814864053 and parameters: {'lambda': 0.06637274639852785, 'alpha': 0.07334474608561742, 'colsample_bytree': 0.8615066292627248, 'subsample': 0.9029979026675335, 'learning_rate': 0.06846435573087695, 'n_estimators': 428, 'max_depth': 8, 'min_child_weight': 16}. Best is trial 155 with value: 442.96497684023586.
# [I 2023-11-03 23:49:54,702] Trial 175 finished with value: 445.18374823994833 and parameters: {'lambda': 0.06474695289816623, 'alpha': 0.11373617460957522, 'colsample_bytree': 0.8351030944981018, 'subsample': 0.846531722788801, 'learning_rate': 0.06184125930129551, 'n_estimators': 335, 'max_depth': 8, 'min_child_weight': 14}. Best is trial 155 with value: 442.96497684023586.
# [I 2023-11-03 23:49:55,031] Trial 176 finished with value: 445.84376613867084 and parameters: {'lambda': 0.06382216518090894, 'alpha': 0.10205879030712611, 'colsample_bytree': 0.8455425248268247, 'subsample': 0.854258526141451, 'learning_rate': 0.0616326764194799, 'n_estimators': 328, 'max_depth': 8, 'min_child_weight': 14}. Best is trial 155 with value: 442.96497684023586.
# [I 2023-11-03 23:49:55,420] Trial 177 finished with value: 446.85491576208574 and parameters: {'lambda': 0.06531348511306681, 'alpha': 0.044055476133276865, 'colsample_bytree': 0.8224883064985509, 'subsample': 0.8444102166389699, 'learning_rate': 0.06613099943175012, 'n_estimators': 383, 'max_depth': 8, 'min_child_weight': 13}. Best is trial 155 with value: 442.96497684023586.
# [I 2023-11-03 23:49:55,625] Trial 178 finished with value: 498.23064488753647 and parameters: {'lambda': 0.06812905222249821, 'alpha': 0.15428554818940568, 'colsample_bytree': 0.8334576376564234, 'subsample': 0.8842745048663647, 'learning_rate': 0.06335853103634438, 'n_estimators': 361, 'max_depth': 5, 'min_child_weight': 11}. Best is trial 155 with value: 442.96497684023586.
# [I 2023-11-03 23:49:55,924] Trial 179 finished with value: 449.0828757511572 and parameters: {'lambda': 0.06165404078471118, 'alpha': 0.12233455033040583, 'colsample_bytree': 0.8571471439164221, 'subsample': 0.8697215498866371, 'learning_rate': 0.06991847275987416, 'n_estimators': 294, 'max_depth': 8, 'min_child_weight': 9}. Best is trial 155 with value: 442.96497684023586.
# [I 2023-11-03 23:49:56,250] Trial 180 finished with value: 446.13578959879777 and parameters: {'lambda': 0.05888568880295554, 'alpha': 0.06464950365653004, 'colsample_bytree': 0.894888476519904, 'subsample': 0.7715288084617259, 'learning_rate': 0.06753314180614312, 'n_estimators': 340, 'max_depth': 8, 'min_child_weight': 14}. Best is trial 155 with value: 442.96497684023586.
# [I 2023-11-03 23:49:56,558] Trial 181 finished with value: 446.1055293875748 and parameters: {'lambda': 0.06352778758188583, 'alpha': 0.11038667525515164, 'colsample_bytree': 0.8676109403967199, 'subsample': 0.8514822575617518, 'learning_rate': 0.07143603641838611, 'n_estimators': 324, 'max_depth': 8, 'min_child_weight': 19}. Best is trial 155 with value: 442.96497684023586.
# [I 2023-11-03 23:49:56,898] Trial 182 finished with value: 445.0932252063371 and parameters: {'lambda': 0.06631014156192662, 'alpha': 0.0883989545335223, 'colsample_bytree': 0.8874977257990171, 'subsample': 0.8709909199737892, 'learning_rate': 0.068911570778772, 'n_estimators': 355, 'max_depth': 8, 'min_child_weight': 16}. Best is trial 155 with value: 442.96497684023586.
# [I 2023-11-03 23:49:57,276] Trial 183 finished with value: 444.53899388866 and parameters: {'lambda': 0.06672982024745448, 'alpha': 0.09466261295978191, 'colsample_bytree': 0.9036031323015921, 'subsample': 0.819475718504695, 'learning_rate': 0.06537885848569974, 'n_estimators': 396, 'max_depth': 8, 'min_child_weight': 15}. Best is trial 155 with value: 442.96497684023586.
# [I 2023-11-03 23:49:57,666] Trial 184 finished with value: 445.2581716194992 and parameters: {'lambda': 0.06649214319403621, 'alpha': 0.07986895422597962, 'colsample_bytree': 0.9057456123169065, 'subsample': 0.8209605364437683, 'learning_rate': 0.06458448649078961, 'n_estimators': 409, 'max_depth': 8, 'min_child_weight': 16}. Best is trial 155 with value: 442.96497684023586.
# [I 2023-11-03 23:49:58,093] Trial 185 finished with value: 447.39784624904354 and parameters: {'lambda': 0.06540458330220812, 'alpha': 0.08205014899788698, 'colsample_bytree': 0.8983027774306832, 'subsample': 0.8127017768553091, 'learning_rate': 0.059237840559780736, 'n_estimators': 440, 'max_depth': 8, 'min_child_weight': 16}. Best is trial 155 with value: 442.96497684023586.
# [I 2023-11-03 23:49:58,507] Trial 186 finished with value: 444.57440700854943 and parameters: {'lambda': 0.06263030404867269, 'alpha': 0.13770125698990676, 'colsample_bytree': 0.9137145322998109, 'subsample': 0.8222381020678485, 'learning_rate': 0.0648190446305192, 'n_estimators': 401, 'max_depth': 8, 'min_child_weight': 12}. Best is trial 155 with value: 442.96497684023586.
# [I 2023-11-03 23:49:58,886] Trial 187 finished with value: 446.14263989746615 and parameters: {'lambda': 0.06661133434698246, 'alpha': 0.14721514708387784, 'colsample_bytree': 0.9137595914996052, 'subsample': 0.8199211152089012, 'learning_rate': 0.062215931979604025, 'n_estimators': 389, 'max_depth': 8, 'min_child_weight': 12}. Best is trial 155 with value: 442.96497684023586.
# [I 2023-11-03 23:49:59,294] Trial 188 finished with value: 447.7882711443108 and parameters: {'lambda': 0.05596736903199743, 'alpha': 0.053797466170106535, 'colsample_bytree': 0.9092800285975083, 'subsample': 0.7987759383598957, 'learning_rate': 0.06470769857510286, 'n_estimators': 412, 'max_depth': 8, 'min_child_weight': 17}. Best is trial 155 with value: 442.96497684023586.
# [I 2023-11-03 23:49:59,644] Trial 189 finished with value: 448.25139989565844 and parameters: {'lambda': 0.06386229062343482, 'alpha': 0.1598463000736878, 'colsample_bytree': 0.9194900220707695, 'subsample': 0.8274817923902457, 'learning_rate': 0.06828931329051514, 'n_estimators': 371, 'max_depth': 8, 'min_child_weight': 15}. Best is trial 155 with value: 442.96497684023586.
# [I 2023-11-03 23:50:00,084] Trial 190 finished with value: 444.94964588561857 and parameters: {'lambda': 0.060889942542547495, 'alpha': 0.08437458296336386, 'colsample_bytree': 0.9020107172696196, 'subsample': 0.8406570923984545, 'learning_rate': 0.060173232248990564, 'n_estimators': 429, 'max_depth': 8, 'min_child_weight': 10}. Best is trial 155 with value: 442.96497684023586.
# [I 2023-11-03 23:50:00,516] Trial 191 finished with value: 446.8604529312696 and parameters: {'lambda': 0.060990926326356776, 'alpha': 0.09047270948051093, 'colsample_bytree': 0.9015706845605644, 'subsample': 0.8407111086494387, 'learning_rate': 0.05904865236970598, 'n_estimators': 427, 'max_depth': 8, 'min_child_weight': 10}. Best is trial 155 with value: 442.96497684023586.
# [I 2023-11-03 23:50:00,925] Trial 192 finished with value: 446.28368776634665 and parameters: {'lambda': 0.06836340802438849, 'alpha': 0.1327349607022724, 'colsample_bytree': 0.8905933705452581, 'subsample': 0.8332699352591735, 'learning_rate': 0.060548245242587825, 'n_estimators': 392, 'max_depth': 8, 'min_child_weight': 9}. Best is trial 155 with value: 442.96497684023586.
# [I 2023-11-03 23:50:01,364] Trial 193 finished with value: 444.1354670945714 and parameters: {'lambda': 0.06565837662760156, 'alpha': 0.07279707575354855, 'colsample_bytree': 0.9269948156039975, 'subsample': 0.8064822646925378, 'learning_rate': 0.06406171448294187, 'n_estimators': 433, 'max_depth': 8, 'min_child_weight': 12}. Best is trial 155 with value: 442.96497684023586.
# [I 2023-11-03 23:50:01,805] Trial 194 finished with value: 445.75674684395113 and parameters: {'lambda': 0.06574707482869796, 'alpha': 0.062406337038473335, 'colsample_bytree': 0.9067093468681349, 'subsample': 0.822850018009272, 'learning_rate': 0.05707972737858896, 'n_estimators': 445, 'max_depth': 8, 'min_child_weight': 12}. Best is trial 155 with value: 442.96497684023586.
# [I 2023-11-03 23:50:02,232] Trial 195 finished with value: 446.6046544093191 and parameters: {'lambda': 0.07357607914788926, 'alpha': 0.0786870833800014, 'colsample_bytree': 0.9206990761537713, 'subsample': 0.8082113303200432, 'learning_rate': 0.062393277774117684, 'n_estimators': 434, 'max_depth': 8, 'min_child_weight': 13}. Best is trial 155 with value: 442.96497684023586.
# [I 2023-11-03 23:50:03,136] Trial 196 finished with value: 446.3239981937296 and parameters: {'lambda': 0.06359909341222449, 'alpha': 0.04023435572197388, 'colsample_bytree': 0.9298808523789416, 'subsample': 0.7993295882196186, 'learning_rate': 0.06446726778467106, 'n_estimators': 416, 'max_depth': 8, 'min_child_weight': 11}. Best is trial 155 with value: 442.96497684023586.
# [I 2023-11-03 23:50:03,527] Trial 197 finished with value: 444.75945708135276 and parameters: {'lambda': 0.06963705066642387, 'alpha': 0.10376860804752717, 'colsample_bytree': 0.8908652462391784, 'subsample': 0.8174646725507255, 'learning_rate': 0.06027699327990444, 'n_estimators': 384, 'max_depth': 8, 'min_child_weight': 13}. Best is trial 155 with value: 442.96497684023586.
# [I 2023-11-03 23:50:03,905] Trial 198 finished with value: 444.040132449297 and parameters: {'lambda': 0.0688717494487031, 'alpha': 0.09326890921863733, 'colsample_bytree': 0.8932529217925689, 'subsample': 0.784866027009267, 'learning_rate': 0.06143656974411978, 'n_estimators': 360, 'max_depth': 8, 'min_child_weight': 10}. Best is trial 155 with value: 442.96497684023586.
# [I 2023-11-03 23:50:04,272] Trial 199 finished with value: 449.4196676942807 and parameters: {'lambda': 0.06908083627007823, 'alpha': 0.0760459228566515, 'colsample_bytree': 0.7681838843324705, 'subsample': 0.7954942199340874, 'learning_rate': 0.06063384112128156, 'n_estimators': 354, 'max_depth': 8, 'min_child_weight': 10}. Best is trial 155 with value: 442.96497684023586.
# Best trial: {'lambda': 0.06711062040812309, 'alpha': 0.05428032704100793, 'colsample_bytree': 0.8762574562285771, 'subsample': 0.898655889433224, 'learning_rate': 0.0787141774346471, 'n_estimators': 267, 'max_depth': 8, 'min_child_weight': 15}
# Best score: 442.96497684023586

# %%
from sklearn.model_selection import KFold
from sklearn.metrics import mean_squared_error

# %%
test_x =test_x.reindex(columns=train_x.columns)

# %%
#Validation : MAE: 729715.7680863414,  Best score: 856.2573364295463,  Best trial: {'lambda': 0.06858310598122817, 'alpha': 0.7713413681986561, 'colsample_bytree': 0.9442346449671033, 'subsample': 0.9750961748574901, 'learning_rate': 0.076433115411846, 'n_estimators': 446, 'max_depth': 8, 'min_child_weight': 16}

#encod_col_v1 : Validation : MAE: 722972.6923, Best score: 864.4005832556281, Best trial: {'lambda': 0.07246551885960752, 'alpha': 0.5233846374744797, 'colsample_bytree': 0.9008060223667523, 'subsample': 0.9996254959269878, 'learning_rate': 0.061161155234371184, 'n_estimators': 753, 'max_depth': 8, 'min_child_weight': 23}


model_xgb = XGBRegressor(**study.best_trial.params)
kf = KFold(n_splits=5, shuffle=True , random_state=20331892)

ensemble_predicts= []
scores =[]


for train_idx, val_idx in tqdm(kf.split(train_x), total=5, desc="Processing folds"):
    X_t, X_val = train_x.iloc[train_idx], train_x.iloc[val_idx]
    y_t, y_val = train_y[train_idx], train_y[val_idx]
    
    # 두 모델 모두 학습
    model_xgb.fit(X_t, y_t)
    
    # 각 모델로부터 Validation set에 대한 예측을 평균내어 앙상블 예측 생성
    val_pred = model_xgb.predict(X_val)
    
    # Validation set에 대한 대회 평가 산식 계산 후 저장
    scores.append(mean_squared_error(y_val, val_pred))
    
    # test 데이터셋에 대한 예측 수행 후 저장
    model_xgb_pred = model_xgb.predict(test_x)
    model_xgb_pred = np.where(model_xgb_pred < 0, 0, model_xgb_pred)
    
    ensemble_predicts.append(model_xgb_pred)

# K-fold 모든 예측의 평균을 계산하여 fold별 모델들의 앙상블 예측 생성
final_predictions = np.mean(ensemble_predicts, axis=0)

# 각 fold에서의 Validation Metric Score와 전체 평균 Validation Metric Score출력
print("Validation : MAE scores for each fold:", scores)
print("Validation : MAE:", np.mean(scores))
# Out:
# Processing folds: 100%|██████████| 5/5 [00:02<00:00,  2.16it/s]
# Validation : MAE scores for each fold: [197201.0902877689, 182232.52566671604, 183098.41183332299, 211919.18835872054, 186713.9918179762]
# Validation : MAE: 192233.04159290093

# %%
final_predictions = np.round(final_predictions, 1)
final_predictions
# Out:
# array([3689.1, 2958.2, 3499.3, ...,  668.1,  630.3,  586. ], dtype=float32)

# %%
submission = pd.read_csv('../../DATA/sample_submission.csv')
submission
# Out:
#                    ID  answer
# 0     TG_A_J_20230304       0
# 1     TG_A_J_20230305       0
# 2     TG_A_J_20230306       0
# 3     TG_A_J_20230307       0
# 4     TG_A_J_20230308       0
# ...               ...     ...
# 1087  RD_F_J_20230327       0
# 1088  RD_F_J_20230328       0
# 1089  RD_F_J_20230329       0
# 1090  RD_F_J_20230330       0
# 1091  RD_F_J_20230331       0
#
# [1092 rows x 2 columns]

# %%
submission['answer'] = final_predictions
# submission.loc[submission.index % 7 == 1, 'answer'] = 0

# %%
submission
# Out:
#                    ID       answer
# 0     TG_A_J_20230304  3689.100098
# 1     TG_A_J_20230305  2958.199951
# 2     TG_A_J_20230306  3499.300049
# 3     TG_A_J_20230307  3392.199951
# 4     TG_A_J_20230308  3388.300049
# ...               ...          ...
# 1087  RD_F_J_20230327   679.200012
# 1088  RD_F_J_20230328   685.900024
# 1089  RD_F_J_20230329   668.099976
# 1090  RD_F_J_20230330   630.299988
# 1091  RD_F_J_20230331   586.000000
#
# [1092 rows x 2 columns]

# %%
submission.to_csv('../../DATA/SUBMIT/new3_opt_xgb_tarenc_sub.csv', index=False)

# %%
sub1 = pd.read_csv('../../DATA/SUBMIT/new_opt_xgb_tarenc_sub.csv')
sub2 = pd.read_csv('../../DATA/SUBMIT/new2_opt_xgb_tarenc_sub.csv')
sub3 = pd.read_csv('../../DATA/SUBMIT/new3_opt_xgb_tarenc_sub.csv')

# %%
sub1['answer'] = sub2['answer']+sub3['answer'] +sub1['answer']

# %%
sub1['answer'] = sub1['answer']/3

# %%
sub1['answer'] =np.round(sub1['answer'],0)

# %%
sub1.to_csv('../../DATA/SUBMIT/new_ens_opt_xgb_tarenc_sub2.csv', index=False)

# %%
sub1
sub1.loc[submission.index % 7 == 1, 'answer'] = 0
