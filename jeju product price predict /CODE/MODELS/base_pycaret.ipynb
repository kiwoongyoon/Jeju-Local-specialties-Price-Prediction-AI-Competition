# %% [markdown]
# ## Import

# %%
import random
import pandas as pd
import numpy as np
import os

from sklearn.ensemble import RandomForestRegressor
from sklearn.preprocessing import LabelEncoder

from pycaret.regression import * 
from pycaret.utils import *
from pycaret import * 

import warnings
warnings.filterwarnings(action='ignore')

# %% [markdown]
# ## Fixed Random-Seed

# %%
def seed_everything(seed):
    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    np.random.seed(seed)

seed_everything(42) # Seed 고정

# %% [markdown]
# ## Load Data

# %%
train_df = pd.read_csv('../../DATA/train.csv')
test_df  = pd.read_csv('../../DATA/test.csv')

# %% [markdown]
# ## Data Pre-Processing

# %%
# 데이터 타입 변경, 열 이름 변경 

new_column_names = {
    'corporation': 'corp',
    'location': 'loc',
    'supply(kg)': 'supply',
    'price(원/kg)': 'price',
}

train_df = train_df.rename(columns=new_column_names)
test_df = test_df.rename(columns=new_column_names)

train_df['timestamp']  = pd.to_datetime(train_df['timestamp'])
test_df['timestamp']  = pd.to_datetime(test_df['timestamp'])

# %%
def get_date_info(data) :
    # data의 날짜 정보 추출하기 
    data['year'] = data['timestamp'].dt.year
    data['month'] = data['timestamp'].dt.month
    data['day'] = data['timestamp'].dt.day
    data['weekday'] = data['timestamp'].dt.weekday
    data['quarter'] = data['timestamp'].dt.quarter

    data['weekofyear'] = data['timestamp'].dt.weekofyear # 해당 년도의 몇 주차 
    data['dayofyear'] = data['timestamp'].dt.dayofyear #해당 년도의 몇 일째 
    
    
get_date_info(train_df)
get_date_info(test_df)

# %%
def trans_fourier(data) :
    #날짜
    data['sin_date'] = -np.sin(2 * np.pi * (data['month']+data['day']/31)/12)
    data['cos_date'] = -np.cos(2 * np.pi * (data['month']+data['day']/31)/12)
    #월
    data['sin_month'] = -np.sin(2 * np.pi * data['month']/12.0)
    data['cos_month'] = -np.cos(2 * np.pi * data['month']/12.0)
    #요일
    data['sin_dayofweek'] = -np.sin(2 * np.pi * (data['weekday']+1)/7.0)
    data['cos_dayofweek'] = -np.cos(2 * np.pi * (data['weekday']+1)/7.0)
    
    
trans_fourier(train_df)
trans_fourier(test_df)

# %%
#학습에 사용하지 않을 변수들을 제거합니다
train_x = train_df.drop(columns=['ID', 'timestamp', 'supply', 'price', 'day', 'month', 'weekday'])
train_y = train_df['price']

test_x = test_df.drop(columns=['ID', 'timestamp' ,  'day', 'month', 'weekday'])

# %%
#질적 변수들을 수치화합니다
qual_col = ['item', 'corp', 'loc']

for i in qual_col:
    le = LabelEncoder()
    train_x[i]=le.fit_transform(train_x[i])
    test_x[i]=le.transform(test_x[i]) #test 데이터에 대해서 fit하는 것은 data leakage에 해당합니다

print('Done.')
# Out:
# Done.

# %%
# pycaret을 위한 설정 
pycaret_train = pd.concat([train_x, train_y], axis= 1)

# %% [markdown]
# ## Pycaret 실행하기

# %%
reg = setup(data = pycaret_train, target='price', session_id= 123, train_size=0.9, use_gpu=True)
# Out:
# [LightGBM] [Fatal] GPU Tree Learner was not enabled in this build.
# Please recompile with CMake option -DUSE_GPU=1
# [LightGBM] [Fatal] CUDA Tree Learner was not enabled in this build.
# Please recompile with CMake option -DUSE_CUDA=1
# [LightGBM] [Fatal] GPU Tree Learner was not enabled in this build.
# Please recompile with CMake option -DUSE_GPU=1
# [LightGBM] [Fatal] CUDA Tree Learner was not enabled in this build.
# Please recompile with CMake option -DUSE_CUDA=1
# [LightGBM] [Fatal] GPU Tree Learner was not enabled in this build.
# Please recompile with CMake option -DUSE_GPU=1
# [LightGBM] [Fatal] CUDA Tree Learner was not enabled in this build.
# Please recompile with CMake option -DUSE_CUDA=1
# [LightGBM] [Fatal] GPU Tree Learner was not enabled in this build.
# Please recompile with CMake option -DUSE_GPU=1
# [LightGBM] [Fatal] CUDA Tree Learner was not enabled in this build.
# Please recompile with CMake option -DUSE_CUDA=1
# [LightGBM] [Fatal] GPU Tree Learner was not enabled in this build.
# Please recompile with CMake option -DUSE_GPU=1
# [LightGBM] [Fatal] CUDA Tree Learner was not enabled in this build.
# Please recompile with CMake option -DUSE_CUDA=1
# [LightGBM] [Fatal] GPU Tree Learner was not enabled in this build.
# Please recompile with CMake option -DUSE_GPU=1
# [LightGBM] [Fatal] CUDA Tree Learner was not enabled in this build.
# Please recompile with CMake option -DUSE_CUDA=1
# [LightGBM] [Fatal] GPU Tree Learner was not enabled in this build.
# Please recompile with CMake option -DUSE_GPU=1
# [LightGBM] [Fatal] CUDA Tree Learner was not enabled in this build.
# Please recompile with CMake option -DUSE_CUDA=1
# [LightGBM] [Fatal] GPU Tree Learner was not enabled in this build.
# Please recompile with CMake option -DUSE_GPU=1
# [LightGBM] [Fatal] CUDA Tree Learner was not enabled in this build.
# Please recompile with CMake option -DUSE_CUDA=1
# [LightGBM] [Fatal] GPU Tree Learner was not enabled in this build.
# Please recompile with CMake option -DUSE_GPU=1
# [LightGBM] [Fatal] CUDA Tree Learner was not enabled in this build.
# Please recompile with CMake option -DUSE_CUDA=1
# [LightGBM] [Fatal] GPU Tree Learner was not enabled in this build.
# Please recompile with CMake option -DUSE_GPU=1
# [LightGBM] [Fatal] CUDA Tree Learner was not enabled in this build.
# Please recompile with CMake option -DUSE_CUDA=1
# [LightGBM] [Fatal] GPU Tree Learner was not enabled in this build.
# Please recompile with CMake option -DUSE_GPU=1
# [LightGBM] [Fatal] CUDA Tree Learner was not enabled in this build.
# Please recompile with CMake option -DUSE_CUDA=1
# [LightGBM] [Fatal] GPU Tree Learner was not enabled in this build.
# Please recompile with CMake option -DUSE_GPU=1
# [LightGBM] [Fatal] CUDA Tree Learner was not enabled in this build.
# Please recompile with CMake option -DUSE_CUDA=1
# <style type="text/css">
# #T_69f86_row8_col1, #T_69f86_row15_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_69f86">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_69f86_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_69f86_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_69f86_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_69f86_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_69f86_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_69f86_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_69f86_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_69f86_row1_col1" class="data row1 col1" >price</td>
#     </tr>
#     <tr>
#       <th id="T_69f86_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_69f86_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_69f86_row2_col1" class="data row2 col1" >Regression</td>
#     </tr>
#     <tr>
#       <th id="T_69f86_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_69f86_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_69f86_row3_col1" class="data row3 col1" >(59397, 14)</td>
#     </tr>
#     <tr>
#       <th id="T_69f86_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_69f86_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_69f86_row4_col1" class="data row4 col1" >(59397, 14)</td>
#     </tr>
#     <tr>
#       <th id="T_69f86_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_69f86_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_69f86_row5_col1" class="data row5 col1" >(53457, 14)</td>
#     </tr>
#     <tr>
#       <th id="T_69f86_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_69f86_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_69f86_row6_col1" class="data row6 col1" >(5940, 14)</td>
#     </tr>
#     <tr>
#       <th id="T_69f86_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_69f86_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_69f86_row7_col1" class="data row7 col1" >13</td>
#     </tr>
#     <tr>
#       <th id="T_69f86_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_69f86_row8_col0" class="data row8 col0" >Preprocess</td>
#       <td id="T_69f86_row8_col1" class="data row8 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_69f86_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_69f86_row9_col0" class="data row9 col0" >Imputation type</td>
#       <td id="T_69f86_row9_col1" class="data row9 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_69f86_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_69f86_row10_col0" class="data row10 col0" >Numeric imputation</td>
#       <td id="T_69f86_row10_col1" class="data row10 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_69f86_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_69f86_row11_col0" class="data row11 col0" >Categorical imputation</td>
#       <td id="T_69f86_row11_col1" class="data row11 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_69f86_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_69f86_row12_col0" class="data row12 col0" >Fold Generator</td>
#       <td id="T_69f86_row12_col1" class="data row12 col1" >KFold</td>
#     </tr>
#     <tr>
#       <th id="T_69f86_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_69f86_row13_col0" class="data row13 col0" >Fold Number</td>
#       <td id="T_69f86_row13_col1" class="data row13 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_69f86_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_69f86_row14_col0" class="data row14 col0" >CPU Jobs</td>
#       <td id="T_69f86_row14_col1" class="data row14 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_69f86_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_69f86_row15_col0" class="data row15 col0" >Use GPU</td>
#       <td id="T_69f86_row15_col1" class="data row15 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_69f86_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_69f86_row16_col0" class="data row16 col0" >Log Experiment</td>
#       <td id="T_69f86_row16_col1" class="data row16 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_69f86_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_69f86_row17_col0" class="data row17 col0" >Experiment Name</td>
#       <td id="T_69f86_row17_col1" class="data row17 col1" >reg-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_69f86_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_69f86_row18_col0" class="data row18 col0" >USI</td>
#       <td id="T_69f86_row18_col1" class="data row18 col1" >35f0</td>
#     </tr>
#   </tbody>
# </table>
# [LightGBM] [Fatal] GPU Tree Learner was not enabled in this build.
# Please recompile with CMake option -DUSE_GPU=1
# [LightGBM] [Fatal] CUDA Tree Learner was not enabled in this build.
# Please recompile with CMake option -DUSE_CUDA=1
# [LightGBM] [Fatal] GPU Tree Learner was not enabled in this build.
# Please recompile with CMake option -DUSE_GPU=1
# [LightGBM] [Fatal] CUDA Tree Learner was not enabled in this build.
# Please recompile with CMake option -DUSE_CUDA=1

# %%
bestmodels = compare_models(fold = 5, n_select=5,  sort='RMSE')

#xgb,rf,lgbm (1157,1196,1206) : 전처리 x
# Out:
# <style type="text/css">
# #T_5b81f th {
#   text-align: left;
# }
# #T_5b81f_row0_col0, #T_5b81f_row0_col5, #T_5b81f_row1_col0, #T_5b81f_row1_col1, #T_5b81f_row1_col2, #T_5b81f_row1_col3, #T_5b81f_row1_col4, #T_5b81f_row1_col5, #T_5b81f_row1_col6, #T_5b81f_row2_col0, #T_5b81f_row2_col1, #T_5b81f_row2_col2, #T_5b81f_row2_col3, #T_5b81f_row2_col4, #T_5b81f_row2_col5, #T_5b81f_row2_col6, #T_5b81f_row3_col0, #T_5b81f_row3_col1, #T_5b81f_row3_col2, #T_5b81f_row3_col3, #T_5b81f_row3_col4, #T_5b81f_row3_col5, #T_5b81f_row3_col6, #T_5b81f_row4_col0, #T_5b81f_row4_col1, #T_5b81f_row4_col2, #T_5b81f_row4_col3, #T_5b81f_row4_col4, #T_5b81f_row4_col6, #T_5b81f_row5_col0, #T_5b81f_row5_col1, #T_5b81f_row5_col2, #T_5b81f_row5_col3, #T_5b81f_row5_col4, #T_5b81f_row5_col5, #T_5b81f_row5_col6, #T_5b81f_row6_col0, #T_5b81f_row6_col1, #T_5b81f_row6_col2, #T_5b81f_row6_col3, #T_5b81f_row6_col4, #T_5b81f_row6_col5, #T_5b81f_row6_col6, #T_5b81f_row7_col0, #T_5b81f_row7_col1, #T_5b81f_row7_col2, #T_5b81f_row7_col3, #T_5b81f_row7_col4, #T_5b81f_row7_col5, #T_5b81f_row7_col6, #T_5b81f_row8_col0, #T_5b81f_row8_col1, #T_5b81f_row8_col2, #T_5b81f_row8_col3, #T_5b81f_row8_col4, #T_5b81f_row8_col5, #T_5b81f_row8_col6, #T_5b81f_row9_col0, #T_5b81f_row9_col1, #T_5b81f_row9_col2, #T_5b81f_row9_col3, #T_5b81f_row9_col4, #T_5b81f_row9_col5, #T_5b81f_row9_col6, #T_5b81f_row10_col0, #T_5b81f_row10_col1, #T_5b81f_row10_col2, #T_5b81f_row10_col3, #T_5b81f_row10_col4, #T_5b81f_row10_col5, #T_5b81f_row10_col6, #T_5b81f_row11_col0, #T_5b81f_row11_col1, #T_5b81f_row11_col2, #T_5b81f_row11_col3, #T_5b81f_row11_col4, #T_5b81f_row11_col5, #T_5b81f_row11_col6, #T_5b81f_row12_col0, #T_5b81f_row12_col1, #T_5b81f_row12_col2, #T_5b81f_row12_col3, #T_5b81f_row12_col4, #T_5b81f_row12_col5, #T_5b81f_row12_col6, #T_5b81f_row13_col0, #T_5b81f_row13_col1, #T_5b81f_row13_col2, #T_5b81f_row13_col3, #T_5b81f_row13_col4, #T_5b81f_row13_col5, #T_5b81f_row13_col6, #T_5b81f_row14_col0, #T_5b81f_row14_col1, #T_5b81f_row14_col2, #T_5b81f_row14_col3, #T_5b81f_row14_col4, #T_5b81f_row14_col5, #T_5b81f_row14_col6, #T_5b81f_row15_col0, #T_5b81f_row15_col1, #T_5b81f_row15_col2, #T_5b81f_row15_col3, #T_5b81f_row15_col4, #T_5b81f_row15_col5, #T_5b81f_row15_col6, #T_5b81f_row16_col0, #T_5b81f_row16_col1, #T_5b81f_row16_col2, #T_5b81f_row16_col3, #T_5b81f_row16_col4, #T_5b81f_row16_col5, #T_5b81f_row16_col6, #T_5b81f_row17_col0, #T_5b81f_row17_col1, #T_5b81f_row17_col2, #T_5b81f_row17_col3, #T_5b81f_row17_col4, #T_5b81f_row17_col5, #T_5b81f_row17_col6 {
#   text-align: left;
# }
# #T_5b81f_row0_col1, #T_5b81f_row0_col2, #T_5b81f_row0_col3, #T_5b81f_row0_col4, #T_5b81f_row0_col6, #T_5b81f_row4_col5 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_5b81f_row0_col7, #T_5b81f_row1_col7, #T_5b81f_row2_col7, #T_5b81f_row3_col7, #T_5b81f_row4_col7, #T_5b81f_row5_col7, #T_5b81f_row6_col7, #T_5b81f_row7_col7, #T_5b81f_row8_col7, #T_5b81f_row9_col7, #T_5b81f_row10_col7, #T_5b81f_row11_col7, #T_5b81f_row12_col7, #T_5b81f_row13_col7, #T_5b81f_row14_col7, #T_5b81f_row16_col7, #T_5b81f_row17_col7 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_5b81f_row15_col7 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_5b81f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5b81f_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_5b81f_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_5b81f_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_5b81f_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_5b81f_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_5b81f_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_5b81f_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_5b81f_level0_col7" class="col_heading level0 col7" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5b81f_level0_row0" class="row_heading level0 row0" >rf</th>
#       <td id="T_5b81f_row0_col0" class="data row0 col0" >Random Forest Regressor</td>
#       <td id="T_5b81f_row0_col1" class="data row0 col1" >306.4638</td>
#       <td id="T_5b81f_row0_col2" class="data row0 col2" >738128.2995</td>
#       <td id="T_5b81f_row0_col3" class="data row0 col3" >859.0649</td>
#       <td id="T_5b81f_row0_col4" class="data row0 col4" >0.8211</td>
#       <td id="T_5b81f_row0_col5" class="data row0 col5" >2.1376</td>
#       <td id="T_5b81f_row0_col6" class="data row0 col6" >0.1900</td>
#       <td id="T_5b81f_row0_col7" class="data row0 col7" >0.5120</td>
#     </tr>
#     <tr>
#       <th id="T_5b81f_level0_row1" class="row_heading level0 row1" >lightgbm</th>
#       <td id="T_5b81f_row1_col0" class="data row1 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_5b81f_row1_col1" class="data row1 col1" >401.4894</td>
#       <td id="T_5b81f_row1_col2" class="data row1 col2" >778643.9202</td>
#       <td id="T_5b81f_row1_col3" class="data row1 col3" >882.2397</td>
#       <td id="T_5b81f_row1_col4" class="data row1 col4" >0.8114</td>
#       <td id="T_5b81f_row1_col5" class="data row1 col5" >3.5058</td>
#       <td id="T_5b81f_row1_col6" class="data row1 col6" >0.2578</td>
#       <td id="T_5b81f_row1_col7" class="data row1 col7" >0.1240</td>
#     </tr>
#     <tr>
#       <th id="T_5b81f_level0_row2" class="row_heading level0 row2" >et</th>
#       <td id="T_5b81f_row2_col0" class="data row2 col0" >Extra Trees Regressor</td>
#       <td id="T_5b81f_row2_col1" class="data row2 col1" >312.8850</td>
#       <td id="T_5b81f_row2_col2" class="data row2 col2" >798179.8892</td>
#       <td id="T_5b81f_row2_col3" class="data row2 col3" >893.2888</td>
#       <td id="T_5b81f_row2_col4" class="data row2 col4" >0.8065</td>
#       <td id="T_5b81f_row2_col5" class="data row2 col5" >2.1041</td>
#       <td id="T_5b81f_row2_col6" class="data row2 col6" >0.1961</td>
#       <td id="T_5b81f_row2_col7" class="data row2 col7" >0.3460</td>
#     </tr>
#     <tr>
#       <th id="T_5b81f_level0_row3" class="row_heading level0 row3" >gbr</th>
#       <td id="T_5b81f_row3_col0" class="data row3 col0" >Gradient Boosting Regressor</td>
#       <td id="T_5b81f_row3_col1" class="data row3 col1" >569.4849</td>
#       <td id="T_5b81f_row3_col2" class="data row3 col2" >1143603.2981</td>
#       <td id="T_5b81f_row3_col3" class="data row3 col3" >1069.3209</td>
#       <td id="T_5b81f_row3_col4" class="data row3 col4" >0.7229</td>
#       <td id="T_5b81f_row3_col5" class="data row3 col5" >4.1330</td>
#       <td id="T_5b81f_row3_col6" class="data row3 col6" >0.3186</td>
#       <td id="T_5b81f_row3_col7" class="data row3 col7" >2.1920</td>
#     </tr>
#     <tr>
#       <th id="T_5b81f_level0_row4" class="row_heading level0 row4" >dt</th>
#       <td id="T_5b81f_row4_col0" class="data row4 col0" >Decision Tree Regressor</td>
#       <td id="T_5b81f_row4_col1" class="data row4 col1" >366.7949</td>
#       <td id="T_5b81f_row4_col2" class="data row4 col2" >1341888.6857</td>
#       <td id="T_5b81f_row4_col3" class="data row4 col3" >1158.2217</td>
#       <td id="T_5b81f_row4_col4" class="data row4 col4" >0.6750</td>
#       <td id="T_5b81f_row4_col5" class="data row4 col5" >2.0605</td>
#       <td id="T_5b81f_row4_col6" class="data row4 col6" >0.2519</td>
#       <td id="T_5b81f_row4_col7" class="data row4 col7" >0.0980</td>
#     </tr>
#     <tr>
#       <th id="T_5b81f_level0_row5" class="row_heading level0 row5" >knn</th>
#       <td id="T_5b81f_row5_col0" class="data row5 col0" >K Neighbors Regressor</td>
#       <td id="T_5b81f_row5_col1" class="data row5 col1" >704.0942</td>
#       <td id="T_5b81f_row5_col2" class="data row5 col2" >1555871.1500</td>
#       <td id="T_5b81f_row5_col3" class="data row5 col3" >1247.2623</td>
#       <td id="T_5b81f_row5_col4" class="data row5 col4" >0.6229</td>
#       <td id="T_5b81f_row5_col5" class="data row5 col5" >3.5399</td>
#       <td id="T_5b81f_row5_col6" class="data row5 col6" >0.5628</td>
#       <td id="T_5b81f_row5_col7" class="data row5 col7"
